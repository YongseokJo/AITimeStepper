# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import TensorDataset, DataLoader, random_split
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("../src/")
import importlib
import structures
importlib.reload(structures)
from structures import *
import losses
importlib.reload(losses)
from losses import *
import trainer
importlib.reload(trainer)
from trainer import *
#dtype = torch.float64
dtype = torch.float32
#dtype = torch.double
torch.set_default_dtype(dtype)
torch.autograd.set_detect_anomaly(True)
# Set the device to CUDA if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

#import deepspeed
import random
sys.path.append("/mnt/home/yjo10/ceph/myutils")
import plt_utils as pu
# Out:
# Using device: cuda

# %%
import torch

class NBodySimulator:
    def __init__(self, 
                 positions: torch.Tensor,  # shape (N, 3)
                 velocities: torch.Tensor,  # shape (N, 3)
                 masses: torch.Tensor,      # shape (N,)
                 G: float = 1.0,            # gravitational constant
                 softening: float = 1e-3,   # softening length to avoid singularities
                 E_eps: float = 1e-6,  # energy conservation threshold
                 device: torch.device = None):
        """
        N-body simulator using PyTorch.

        Args:
            positions: initial positions (N, 3)
            velocities: initial velocities (N, 3)
            masses:       masses of bodies (N,)
            G:            gravitational constan
            
            softening:    softening parameter ε
            device:       torch.device (cpu or cuda)
        """
        self.device = device or torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.x = positions.to(self.device)
        self.v = velocities.to(self.device)
        self.m = masses.to(self.device).view(-1, 1)  # (N,1) for broadcasting
        self.G = G
        self.eps = softening
        self.E_eps = E_eps
        self.E = self.total_energy()
        self.P = self.total_momentum()

    def pairwise_forces(self):
        """
        Compute pairwise gravitational forces:
        F_i = G * sum_j m_i*m_j * (x_j - x_i) / (|x_j - x_i|^2 + eps^2)^(3/2)
        Returns:
            forces: Tensor of shape (N, 3)
        """
        # Compute pairwise displacement vectors: (N,1,3) - (1,N,3) -> (N,N,3)
        dx = self.x.unsqueeze(1) - self.x.unsqueeze(0)
        # squared distances with softening
        dist_sqr = (dx**2).sum(dim=2) + self.eps**2  # (N,N)
        dist_sqr_safe = dist_sqr.clamp(min=self.eps)      # never below eps^2
        inv_dist3    = dist_sqr_safe.pow(-1.5)               # (N,N)
        #inv_dist3 = torch.nan_to_num(inv_dist3, nan=0.0, posinf=0.0, neginf=0.0)
        # weight by masses: m_i * m_j
        weight = -self.G * (self.m * self.m.T)       # (N,N)
        # force matrix: weight * inv_dist3 * dx
        F = (weight.unsqueeze(2) * inv_dist3.unsqueeze(2)) * dx  # (N,N,3)
        self.F = F.sum(dim=1)
        # sum over j
        return  self.F

    def step(self, dt: float):
        """
        Advance the system by one time-step dt using velocity-Verlet:
        x(t+dt) = x(t) + v(t)*dt + 0.5*a(t)*dt^2
        compute new a(t+dt), then
        v(t+dt) = v(t) + 0.5*(a(t) + a(t+dt))*dt
        """
        # current acceleration
        a = self.pairwise_forces() / self.m
        # update positions
        self.x = self.x + self.v * dt + 0.5 * a * dt**2
        # compute new acceleration
        a_new = self.pairwise_forces() / self.m
        # update velocities
        self.v = self.v + 0.5 * (a + a_new) * dt

    def run(self, steps: int, dt: float, record: bool = False):
        """
        Run the simulation.

        Args:
            steps: number of steps
            dt:    time-step
            record: if True, return trajectory arrays
        Returns:
            If record=True:
                positions_history: Tensor (steps+1, N, 3)
                velocities_history: Tensor (steps+1, N, 3)
            else: None
        """
        if record:
            xs = [self.x.clone()]
            vs = [self.v.clone()]

        for _ in range(steps):
            self.step(dt)
            if record:
                xs.append(self.x.clone())
                vs.append(self.v.clone())

        if record:
            return torch.stack(xs), torch.stack(vs)

    def kinetic_energy(self):
        # K = 1/2 sum_i m_i v_i^2
        v2 = (self.v**2).sum(dim=1, keepdim=True)           # (N,1)
        return 0.5 * (self.m * v2).sum()

    def potential_energy(self):
        # U = -1/2 G sum_{i!=j} m_i m_j / r_ij
        dx = self.x.unsqueeze(1) - self.x.unsqueeze(0)      # (N,N,3)
        dist = torch.sqrt((dx**2).sum(dim=2) + self.eps**2)  # (N,N)
        dist_safe = dist.clamp(min=self.eps)      # never below eps^2
        mass_prod = self.m * self.m.T                       # (N,N)
        inv_r = 1.0 / dist_safe
        #inv_r = torch.nan_to_num(inv_r, nan=0.0, posinf=0.0, neginf=0.0)
        U = -0.5 * self.G * (mass_prod * inv_r).sum()
        return U

    def total_energy(self):
        return self.kinetic_energy() + self.potential_energy()

    def total_momentum(self):
        # P = sum_i m_i v_i  -> (3,)
        P = (self.m * self.v).sum(dim=0)
        return P


    def run_with_diagnostics(self, steps, dt, record=True):
        """
        Runs the sim and returns histories of energy & momentum.
        """
        if record:
            E_hist = []
            P_hist = []
            # record initial
            E_hist.append(self.total_energy().item())
            P_hist.append(self.total_momentum().cpu().numpy())

            xs = [self.x.clone()]
            vs = [self.v.clone()]

        for _ in range(steps):
            self.step(dt)
            if record:
                E_hist.append(self.total_energy().item())
                P_hist.append(self.total_momentum().cpu().numpy())
                xs.append(self.x.clone())
                vs.append(self.v.clone())

        return torch.stack(xs), torch.stack(vs), torch.tensor(E_hist), torch.tensor(P_hist)  # shapes (steps+1,), (steps+1,3)

    def step_diagnostics(self, dt):
        """
        Perform a single step and return diagnostics.
        """

        # current acceleration
        a = self.F / self.m
        # update positions
        self.x_new = self.x + self.v * dt + 0.5 * a * dt**2
        # compute new acceleration
        a_new = self.F / self.m
        # update velocities
        self.v_new = self.v + 0.5 * (a + a_new) * dt

        E = self.total_energy()
        P = self.total_momentum()
        dE = torch.abs((self.E - E)/self.E)
        if dE > self.E_eps:
            _next = False
        else:
            self.x = self.x_new
            self.v = self.v_new
            self.E = E
            self.P = P
            _next = True
            #dE += torch.abs(self.E_eps/self.E)  # ensure non-zero dE
            dE = dE + torch.abs(self.E_eps / self.E)
            
        return _next, dE

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

def plot_trajectories(positions_hist):
    """
    Static plot of each particle's XY trajectory.
    
    positions_hist: np.ndarray, shape (T, N, 3)
    """
    T, N, _ = positions_hist.shape
    plt.figure()
    for i in range(N):
        xs = positions_hist[:, i, 0]
        ys = positions_hist[:, i, 1]
        plt.scatter(xs[0], ys[0], c="red")
        plt.plot(xs, ys)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Particle Trajectories (XY-plane)')
    plt.show()


def animate_particles(positions_hist, *, interval=50, skip=1, save_path=None):
    """
    Create and display (and optionally save) an animation of the N bodies.
    
    positions_hist: np.ndarray, shape (T, N, 3)
    interval: ms between frames
    skip: show every `skip`-th frame
    save_path: if given (e.g. 'nbody.mp4'), will save the animation to that file
    """
    T, N, _ = positions_hist.shape
    fig, ax = plt.subplots()
    scat = ax.scatter([], [], s=50)

    # Set plot limits based on full trajectory
    all_x = positions_hist[:, :, 0]
    all_y = positions_hist[:, :, 1]
    ax.set_xlim(all_x.min(), all_x.max())
    ax.set_ylim(all_y.min(), all_y.max())
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('N-body Particle Animation (XY-plane)')

    def init():
        scat.set_offsets([])
        return scat,

    def update(frame_idx):
        frame = frame_idx * skip
        data = positions_hist[frame, :, :2]  # only x,y
        scat.set_offsets(data)
        return scat,

    ani = FuncAnimation(
        fig, update,
        frames=range(0, T//skip),
        init_func=init,
        interval=interval,
        blit=True
    )

    if save_path:
        # Requires ffmpeg installed in your environment
        ani.save(save_path, fps=1000//interval)
        print(f"Animation saved to {save_path}")

    plt.show()

# %%
# Example usage: 3-body problem
N = 3
torch.manual_seed(0)
pos = torch.randn(N, 3) * 1.0
vel = torch.randn(N, 3) * 0.1
mass = torch.rand(N) * 5 + 1  # masses in [1,6)

# %%
T = 1.1
steps = 10000
dt = float(T/steps)

sim = NBodySimulator(pos, vel, mass, G=1.0, softening=1e-2)
#positions_hist, _ = sim.run(steps=steps, dt=dt, record=True)
positions_hist, _ , E, P = sim.run_with_diagnostics(steps=steps, dt=dt, record=True)
positions_hist = positions_hist.cpu().numpy()
E = E.cpu().numpy()
P = P.cpu().numpy()

# %%
plot_trajectories(positions_hist)
plt.plot(range(steps+1), E)
plt.show()
plt.plot(range(steps+1), np.linalg.norm(P,axis=1))
plt.show()

# %% [markdown]
# ## Training

# %%
torch.autograd.set_detect_anomaly(True)

# %%
# --- Build your MLP predictor ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = nn.Sequential(
    nn.Linear(9, 64), nn.ReLU(),
    nn.Linear(64, 64), nn.ReLU(),
    nn.Linear(64, 1)
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn   = nn.MSELoss()

# --- Online training loop ---
def train_online(epochs=20, 
                N=64,           # particles per sim
                steps_per_epoch=10, 
                E_eps=1e-2,
                device=device
                ):
    loss_history = [] 
    for ep in range(1, epochs+1):
        # 1) Random initial conditions each epoch
        pos  = torch.randn(N, 3, device=device)
        vel  = torch.randn(N, 3, device=device) * 0.1
        mass = torch.rand(N, device=device) * 5 + 1

        sim = NBodySimulator(pos, vel, mass, E_eps=E_eps, device=device)

        running_loss = 0.0
        count        = 0
        _next = True

        # 2) Evolve and train on-the-fly
        for _step in range(steps_per_epoch):

            optimizer.zero_grad()
            while (True):
              if _next:
                # a) compute features & labels
                sim.pairwise_forces() # compute forces to update a_norm
                features = torch.cat([sim.x, sim.v, sim.F], dim=1)  # (N,7)

              dt_pred = torch.abs(model(features))
              #with torch.no_grad():
              _next, dE = sim.step_diagnostics(torch.mean(dt_pred))            # (N,), (N,)

              # b) forward + loss
              if _next:
                loss  =  -torch.sum(dt_pred.squeeze()**2)              
              else:
                loss  =  torch.sum((torch.log(dE)-10)**2) #loss_fn(dt_pred.squeeze(), E)            # scalar
              # c) backward + step optimizer
              #loss.backward()
              loss.backward(retain_graph=True)
              if _next:
                break

            optimizer.step()
            running_loss += loss.item() * N
            count       += N

        avg_loss = running_loss / count
        loss_history.append(avg_loss)   # ← append here
        print(f"Epoch {ep}/{epochs} — Avg MSE: {avg_loss:.6f}")
    return loss_history               # ← return the history
# Run training
loss_hist = train_online(epochs=30, N=3, steps_per_epoch=20)


# Plot the learning curve
plt.figure()
plt.plot(range(1, len(loss_hist)+1), loss_hist, marker='o')
plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Average MSE Loss')
plt.title('Learning Curve of Timestep Predictor')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/autograd/__init__.py:266: UserWarning: Error detected in AddmmBackward0. Traceback of forward call that caused the error:
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2035880/2656041283.py", line 66, in <module>
#     loss_hist = train_online(epochs=30, N=3, steps_per_epoch=20)
#   File "/tmp/ipykernel_2035880/2656041283.py", line 42, in train_online
#     dt_pred = torch.abs(model(features))
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/nn/modules/container.py", line 217, in forward
#     input = module(input)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/nn/modules/linear.py", line 116, in forward
#     return F.linear(input, self.weight, self.bias)
#  (Triggered internally at /dev/shm/nix-build-py-torch-2.2.2.drv-0/nixbld1/spack-stage-py-torch-2.2.2-mrga1lajkybghn1l6sc83lyspvbakfzk/spack-src/torch/csrc/autograd/python_anomaly_mode.cpp:113.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[159], line 66
#      64     return loss_history               # ← return the history
#      65 # Run training
# ---> 66 loss_hist = train_online(epochs=30, N=3, steps_per_epoch=20)
#      69 # Plot the learning curve
#      70 plt.figure()
#
# Cell In[159], line 53, in train_online(epochs, N, steps_per_epoch, E_eps, device)
#      50   loss  =  torch.sum((torch.log(dE)-10)**2) #loss_fn(dt_pred.squeeze(), E)            # scalar
#      51 # c) backward + step optimizer
#      52 #loss.backward()
# ---> 53 loss.backward(retain_graph=True)
#      54 if _next:
#      55   break
#
# File /mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File /mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# RuntimeError: one of the variables needed for gradient computation has been modified by an inplace operation: [torch.cuda.FloatTensor [64, 1]], which is output 0 of AsStridedBackward0, is at version 2; expected version 1 instead. Hint: the backtrace further above shows the operation that failed to compute its gradient. The variable in question was changed in there or anywhere later. Good luck!

# %%
import torch
import torch.nn as nn

# --- Physics helper functions ---
def pairwise_forces(x: torch.Tensor,
                    m: torch.Tensor,
                    G: float,
                    eps: float) -> torch.Tensor:
    """
    Compute gravitational forces on each of N particles.
    x: (N,3), m: (N,1)
    Returns F: (N,3)
    """
    # (N,1,3) - (1,N,3) -> (N,N,3)
    dx = x.unsqueeze(1) - x.unsqueeze(0)
    # squared distances with softening
    dist2 = (dx*dx).sum(dim=2) + eps*eps   # (N,N)
    # avoid singularity
    inv3  = dist2.clamp(min=eps*eps).pow(-1.5)  # (N,N)
    # mass‐product matrix
    Mmat  = (m * m.T)                         # (N,N)
    # force matrix: G * Mmat * inv3 * dx
    F     = G * Mmat.unsqueeze(-1) * inv3.unsqueeze(-1) * dx  # (N,N,3)
    # sum over j
    return F.sum(dim=1)   # (N,3)

def total_energy(x: torch.Tensor,
                 v: torch.Tensor,
                 m: torch.Tensor,
                 G: float,
                 eps: float) -> torch.Tensor:
    """
    Compute total energy K + U of the system.
    """
    # kinetic
    K = 0.5 * (m * (v*v).sum(dim=1, keepdim=True)).sum()
    # potential
    dx   = x.unsqueeze(1) - x.unsqueeze(0)
    dist = dx.pow(2).sum(dim=2).sqrt().clamp(min=eps)  # (N,N)
    U    = -0.5 * G * ((m*m.T) / dist).sum()
    return K + U

def total_momentum(v: torch.Tensor,
                   m: torch.Tensor) -> torch.Tensor:
    """
    Compute total momentum P = sum_i m_i * v_i.
    """
    return (m * v).sum(dim=0)  # (3,)

# --- One-step functional integrator + diagnostics ---
def step_diagnostics_fn(x: torch.Tensor,
                        v: torch.Tensor,
                        m: torch.Tensor,
                        F: torch.Tensor,
                        E: torch.Tensor,
                        P: torch.Tensor,
                        G: float,
                        eps: float,
                        E_eps: float,
                        dt: torch.Tensor):
    """
    Given state (x,v,E,P), propose one velocity‐Verlet step of size dt,
    compute fractional energy change and acceptance, without mutating inputs.
    Returns: x_new, v_new, E_new, P_new, accept (bool), dE (scalar tensor)
    """
    # 1) current acceleration
    a      = F / m                           # (N,3)

    # 2) propose new positions
    x_new  = x + v * dt + 0.5 * a * dt*dt    # (N,3)

    # 3) propose new velocities
    v_new  = v + a * dt      # (N,3)

    # 5) compute new energy & momentum
    E_new  = total_energy(x_new, v_new, m, G, eps)  # scalar
    P_new  = total_momentum(v_new, m)               # (3,)

    # 6) fractional energy change
    dE     = torch.abs((E - E_new) / E)             # scalar

    # 7) acceptance criterion
    accept = dE <= E_eps

    # 8) bump dE so it's never exactly zero on accept
    dE     = torch.where(
        accept,
        dE + torch.abs(E_eps / E),
        dE
    )

    return x_new, v_new, E_new, P_new, accept, dE

# --- Build the MLP predictor ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = nn.Sequential(
    nn.Linear(7, 64), nn.ReLU(),
    nn.Linear(64, 64), nn.ReLU(),
    nn.Linear(64, 1)
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn   = nn.MSELoss()

# --- Training loop ---
def train(num_epochs: int = 10,
          N: int = 32,
          max_steps: int = 20,
          G: float = 1.0,
          eps: float = 1e-2,
          E_eps: float = 1e-3):
    loss_history = []

    for epoch in range(1, num_epochs + 1):
        # 1) initialize fresh system
        x  = torch.randn(N, 3, device=device)
        v  = torch.randn(N, 3, device=device) * 0.1
        m  = (torch.rand(N, 1, device=device) * 5.0) + 1.0

        # 2) compute initial diagnostics
        E  = total_energy(x, v, m, G, eps)
        P  = total_momentum(v, m)

        losses = []

        # 3) run up to max_steps
        for _ in range(max_steps):
            # a) compute current acceleration for features
            F   = pairwise_forces(x, m, G, eps)    # (N,3)
            a   = F / m                            # (N,3)
            a_n = torch.norm(a, dim=1, keepdim=True)  # (N,1)

            # b) build features: [x,y,z, vx,vy,vz, |a|]
            features = torch.cat([x, v, a_n], dim=1)   # (N,7)

            # c) predict dt per particle, take mean as step size
            dt_pred = torch.abs(model(features))       # (N,1)
            dt      = dt_pred.mean()                   # scalar

            # d) step forward and get diagnostics
            x, v, E, P, accept, dE = step_diagnostics_fn(
                x, v, m, F, E, P, G, eps, E_eps, dt
            )

            # e) accumulate loss
            if accept:
                # encourage large dt_pred when stable
                losses.append(-(dt_pred**2).sum())
                break
            else:
                # penalize when energy drift gets too large
                losses.append(((torch.log(dE) - 10.0)**2).sum())

        # 4) backward through the entire trajectory
        total_loss = torch.stack(losses).sum()
        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()

        loss_history.append(total_loss.item())
        print(f"Epoch {epoch}/{num_epochs} — loss = {total_loss.item():.6f}")

    return loss_history

# --- Run training ---
history = train(num_epochs=20, N=64, max_steps=30)
# Optionally, plot history here with matplotlib
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 103
#      95 device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#      97 model = nn.Sequential(
#      98     nn.Linear(7, 64), nn.ReLU(),
#      99     nn.Linear(64, 64), nn.ReLU(),
#     100     nn.Linear(64, 1)
#     101 ).to(device)
# --> 103 optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
#     104 loss_fn   = nn.MSELoss()
#     106 # --- Training loop ---
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/optim/adam.py:100, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused, decoupled_weight_decay)
#      85         raise ValueError("Tensor betas[1] must be 1-element")
#      87 defaults = dict(
#      88     lr=lr,
#      89     betas=betas,
#    (...)
#      98     decoupled_weight_decay=decoupled_weight_decay,
#      99 )
# --> 100 super().__init__(params, defaults)
#     102 if fused:
#     103     if differentiable:
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/optim/optimizer.py:369, in Optimizer.__init__(self, params, defaults)
#     366     param_groups = [{"params": param_groups}]
#     368 for param_group in param_groups:
# --> 369     self.add_param_group(cast(dict, param_group))
#     371 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     372 # which I don't think exists
#     373 # https://github.com/pytorch/pytorch/issues/72948
#     374 self._warned_capturable_if_run_uncaptured = True
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_compile.py:46, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      44 disable_fn = getattr(fn, "__dynamo_disable", None)
#      45 if disable_fn is None:
# ---> 46     import torch._dynamo
#      48     disable_fn = torch._dynamo.disable(fn, recursive)
#      49     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/__init__.py:53
#      49 from .utils import graph_break_reasons, guard_failures, orig_code_map, reset_frame_count
#      52 # Register polyfill functions
# ---> 53 from .polyfills import loader as _  # usort: skip # noqa: F401
#      56 __all__ = [
#      57     "allow_in_graph",
#      58     "assume_constant_result",
#    (...)
#      82     "config",
#      83 ]
#      85 # allowlist this for weights_only load of NJTs
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/polyfills/loader.py:25
#      14 # See also the TYPE_CHECKING block in torch/_dynamo/polyfills/__init__.py
#      15 POLYFILLED_MODULE_NAMES: tuple[str, ...] = (
#      16     "builtins",
#      17     "functools",
#    (...)
#      23     "fx",
#      24 )
# ---> 25 POLYFILLED_MODULES: tuple["ModuleType", ...] = tuple(
#      26     importlib.import_module(f".{submodule}", package=polyfills.__name__)
#      27     for submodule in POLYFILLED_MODULE_NAMES
#      28 )
#      31 # Unregister the builtin functions from _builtin_function_ids to let them to be
#      32 # dispatched with the appropriate VariableTracker type. Otherwise, they will be
#      33 # dispatched with BuiltinVariable if present in _builtin_function_ids.
#      34 for polyfill_module in POLYFILLED_MODULES:
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/polyfills/loader.py:26, in <genexpr>(.0)
#      14 # See also the TYPE_CHECKING block in torch/_dynamo/polyfills/__init__.py
#      15 POLYFILLED_MODULE_NAMES: tuple[str, ...] = (
#      16     "builtins",
#      17     "functools",
#    (...)
#      23     "fx",
#      24 )
#      25 POLYFILLED_MODULES: tuple["ModuleType", ...] = tuple(
# ---> 26     importlib.import_module(f".{submodule}", package=polyfills.__name__)
#      27     for submodule in POLYFILLED_MODULE_NAMES
#      28 )
#      31 # Unregister the builtin functions from _builtin_function_ids to let them to be
#      32 # dispatched with the appropriate VariableTracker type. Otherwise, they will be
#      33 # dispatched with BuiltinVariable if present in _builtin_function_ids.
#      34 for polyfill_module in POLYFILLED_MODULES:
#
# File /mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/polyfills/builtins.py:31
#      19 __all__ = [
#      20     "all",
#      21     "any",
#      22     "enumerate",
#      23     "sum",
#      24 ]
#      27 _T = TypeVar("_T")
#      30 @substitute_in_graph(builtins.all, can_constant_fold_through=True)
# ---> 31 def all(iterable: Iterable[object], /) -> bool:
#      32     for elem in iterable:
#      33         if not elem:
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/decorators.py:427, in substitute_in_graph.<locals>.wrapper(traceable_fn)
#     424 if id(original_fn) in _polyfilled_function_ids:
#     425     raise ValueError(f"Duplicate polyfilled object {original_fn}")
# --> 427 rule_map: dict[Any, type[VariableTracker]] = get_torch_obj_rule_map()
#     428 if original_fn in rule_map:
#     429     raise ValueError(
#     430         f"Duplicate object {original_fn} with different rules: "
#     431         f"{PolyfilledFunctionVariable}, {rule_map[original_fn]}"
#     432     )
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/trace_rules.py:2870, in get_torch_obj_rule_map()
#    2868 for k, v in m.items():  # type: ignore[attr-defined]
#    2869     if ".py#" not in k:
# -> 2870         obj = load_object(k)
#    2871     else:
#    2872         obj = _module_dir(torch) + k[len("torch/") :]
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/trace_rules.py:2901, in load_object(name)
#    2899     else:
#    2900         assert len(x) == 1, f"Invalid obj name {name}"
# -> 2901         val = _load_obj_from_str(x[0])
#    2902     val = unwrap_if_wrapper(val)
#    2903 except (AttributeError, ImportError):
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_dynamo/trace_rules.py:2885, in _load_obj_from_str(fully_qualified_name)
#    2883 def _load_obj_from_str(fully_qualified_name):
#    2884     module, obj_name = fully_qualified_name.rsplit(".", maxsplit=1)
# -> 2885     return getattr(importlib.import_module(module), obj_name)
#
# File /mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_higher_order_ops/map.py:6
#       4 from torch._C import DispatchKey
#       5 from torch._dispatch.python import suspend_functionalization
# ----> 6 from torch._functorch.aot_autograd import AOTConfig, create_joint
#       7 from torch._higher_order_ops.utils import (
#       8     _has_potential_branch_input_alias,
#       9     _has_potential_branch_input_mutation,
#    (...)
#      12     UnsupportedAliasMutationException,
#      13 )
#      14 from torch._ops import HigherOrderOperator
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_functorch/aot_autograd.py:135
#     112 from ._aot_autograd.traced_function_transforms import (  # noqa: F401
#     113     aot_dispatch_subclass,
#     114     create_functional_call,
#    (...)
#     119     fn_prepped_for_autograd,
#     120 )
#     121 from ._aot_autograd.utils import (  # noqa: F401
#     122     _get_autocast_states,
#     123     _get_symint_hints,
#    (...)
#     133     strict_zip,
#     134 )
# --> 135 from .partitioners import default_partition
#     138 zip = strict_zip
#     140 # This global counter increments every time we compile a graph with
#     141 # AOTAutograd.  You can use this to correlate runtime error messages
#     142 # with compile time (e.g., if you get an error at runtime saying
#    (...)
#     149 # one counter is allocated per entire compiled block (but this block
#     150 # may involve compiling multiple subgraphs; e.g., for forwards/backwards)
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_functorch/partitioners.py:37
#      34 from torch.utils.checkpoint import CheckpointPolicy
#      36 from . import config
# ---> 37 from ._activation_checkpointing.graph_info_provider import GraphInfoProvider
#      38 from ._activation_checkpointing.knapsack import (
#      39     dp_knapsack,
#      40     greedy_knapsack,
#      41     ilp_knapsack,
#      42 )
#      43 from ._activation_checkpointing.knapsack_evaluator import KnapsackEvaluator
#
# File ~/pyenv/torch/lib/python3.10/site-packages/torch/_functorch/_activation_checkpointing/graph_info_provider.py:3
#       1 from typing import Any, Optional
# ----> 3 import networkx as nx
#       5 from torch.fx import Graph, Node
#       8 class GraphInfoProvider:
#
# File /mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/networkx/__init__.py:42
#      39 from networkx.readwrite import *
#      41 # Need to test with SciPy, when available
# ---> 42 from networkx import algorithms
#      43 from networkx.algorithms import *
#      45 from networkx import linalg
#
# File /mnt/sw/nix/store/71ksmx7k6xy3v9ksfkv5mp5kxxp64pd6-python-3.10.13-view/lib/python3.10/site-packages/networkx/algorithms/__init__.py:62
#      58 from networkx.algorithms.polynomials import *
#      60 # Make certain subpackages available to the user as direct imports from
#      61 # the `networkx` namespace.
# ---> 62 from networkx.algorithms import approximation
#      63 from networkx.algorithms import assortativity
#      64 from networkx.algorithms import bipartite
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1002, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:945, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1439, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1411, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1563, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:161, in _path_isfile(path)
#
# File <frozen importlib._bootstrap_external>:153, in _path_is_mode_type(path, mode)
#
# File <frozen importlib._bootstrap_external>:147, in _path_stat(path)
#
# KeyboardInterrupt:

# %%
# — physics helpers from before (pairwise_forces, total_energy, total_momentum) —
def pairwise_forces(x,m,G,eps):
    dx    = x.unsqueeze(1) - x.unsqueeze(0)
    dist2 = (dx*dx).sum(-1) + eps*eps
    inv3  = dist2.clamp(min=eps*eps).pow(-1.5)
    F     = -G * (m*m.T).unsqueeze(-1) * inv3.unsqueeze(-1) * dx
    return F.sum(1)

def total_energy(x,v,m,G,eps):
    K = 0.5 * (m*(v*v).sum(1,keepdim=True)).sum()
    dx   = x.unsqueeze(1)-x.unsqueeze(0) + eps
    dist = dx.pow(2).sum(-1).sqrt() #.clamp(min=eps)
    U    = -0.5*G*((m*m.T)/dist).sum()
    return K+U

def total_momentum(v,m):
    return (m*v).sum(0)

def step_diagnostics_fn(x, v, m, F, E, P, G, eps, E_eps, dt):
    # compute accel
    a     = F/m
    # propose step
    x_new = x + v*dt + 0.5*a*dt*dt
    v_new = v +a*dt
    # diagnostics
    E_new = total_energy(x_new, v_new, m, G, eps)
    P_new = total_momentum(v_new, m)
    dE    = torch.abs((E - E_new)/E)
    eps_log = 1e-8
    accept= dE <= E_eps
    return x_new, v_new, E_new, P_new, accept, dE

# — build your MLP —
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = nn.Sequential(
    nn.Linear(7,64), nn.ReLU(),
    nn.Linear(64,64), nn.ReLU(),
    nn.Linear(64,1)
).to(device)

opt   = torch.optim.Adam(model.parameters(), lr=1e-4)

# — per-step online training —
def train_online_per_step(epochs=10, N=64, max_steps=20,
                          G=1.0, eps=1e-2, E_eps=1e-3, max_attempts=100):
    accept = torch.tensor(True)
    for ep in range(1, epochs+1):
        # init state
        x = torch.randn(N,3, device=device)
        v = torch.randn(N,3, device=device)*0.1
        m = (torch.rand(N,1,device=device)*5.0)+1.0
        E = total_energy(x,v,m,G,eps)
        P = total_momentum(v,m)

        step_losses = []
        for step in range(1, max_steps+1):
            print(f"Epoch {ep} step {step} starts")
            # detach state so graph starts clean
            #x = x.detach().clone().requires_grad_(True)
            #v = v.detach().clone().requires_grad_(True)
            #E = E.detach().clone().requires_grad_(True)
            #P = P.detach().clone()

            # build features [x,y,z, vx,vy,vz, |a|]
            #F   = pairwise_forces(x,m,G,eps)
            #F = F.detach()
            #print(F)
            #a   = F/m
            #a_n = torch.norm(a, dim=1, keepdim=True)
            #feats = torch.cat([x, v, a_n], dim=1)
            x_old = x.clone()
            v_old = v.clone()
            E_old = E.clone()
            F = pairwise_forces(x,m,G,eps)
            a   = F/m
            a_n = torch.norm(a, dim=1, keepdim=True)
            a_n_old = a_n.clone()
            attempt = 0
            while attempt < max_attempts:
                x = x_old.detach().clone().requires_grad_(True)
                v = v_old.detach().clone().requires_grad_(True)
                E = E_old.detach().clone()#.requires_grad_(True)
                F = F.detach().clone()#.requires_grad_(True)
                a_n = a_n_old.detach()#.clone().requires_grad_(True)
                m = m.detach().clone()
                #x = x_old.clone()
                #v = v_old.clone()
                #E = E_old.clone()
                # predict dt and step
                #F = F.detach()
                #print(F)

                feats = torch.cat([x, v, a_n], dim=1)
                #print(feats)
                dt_pred = torch.abs(model(feats))      # (N,1)
                #print(dt_pred)
                dt_pred = dt_pred.clamp(min=1e-6, max=1.0)
                dt      = dt_pred.mean()               # scalar
                #print(dt)

                if accept.item() is False:
                    print(dt)
                    print(x,v,E,F,P,a_n,m)
                #    print(accept)
                    #raise

                #x, v, E, P, accept, dE = step_diagnostics_fn(
                x_new, v_new, E_new, P_new, accept, dE = step_diagnostics_fn(
                    x, v, m, F, E, P, G, eps, E_eps, dt
                )

                # define your loss for this step
                if accept:
                    loss = -(dt_pred**2).mean()        # encourage large stable dt
                    #loss = ((torch.log(dE))**2).mean()
                    #safe_dE  = dE.clamp(min=1e-4, max=10.0)
                    #loss = torch.sum((torch.log(dE+1e-4)+4)**2)
                    #print(dE, loss, accept)
                else:
                    #loss = ((torch.log(dE))**2).mean()
                    #loss = (torch.log(dE + eps_log)**2).mean()
                    loss = torch.sum((torch.log(dE+1e-10)-np.log(1e-10))**2)
                    #loss = (dt_pred**2).mean()        # encourage large stable dt
                    print(dE, loss, accept)
                    if torch.isnan(loss):
                        raise

                # backward & optimize for this single step
                opt.zero_grad()
                #loss.backward(retain_graph=True)  # retain graph for next step
                loss.backward()  # retain graph for next step
                opt.step()

                # 3) After your optimizer.step(), check the weights
                for name, param in model.named_parameters():
                    if torch.isnan(param).any() or torch.isinf(param).any():
                        print(f"⚠️  NaN/Inf in weights at {name}")
                        # as a drastic measure, zero out bad grads or reset weights
                        param.data = torch.nan_to_num(param.data, nan=0.0, posinf=1.0, neginf=-1.0)

                if accept:
                    print(f"Epoch {ep} step {step}: accepted, loss={loss.item():.4e}")
                    break
                else:
                    print(f"Epoch {ep} step {step}: rejected, loss={loss.item():.4e}")
                    attempt += 1

            x, v, E, P = x_new, v_new, E_new, P_new
            step_losses.append(loss.item())

        avg_loss = sum(step_losses)/len(step_losses)
        print(f"→ Epoch {ep} done, avg per-step loss = {avg_loss:.4e}\n")

if __name__=="__main__":
    train_online_per_step(epochs=10, N=3, max_steps=20,
                            G=1.0, eps=1e-5, E_eps=1e-3)
# Out:
# Epoch 1 step 1 starts
# Epoch 1 step 1: accepted, loss=-1.1058e-03
# Epoch 1 step 2 starts
# Epoch 1 step 2: accepted, loss=-1.2323e-03
# Epoch 1 step 3 starts
# Epoch 1 step 3: accepted, loss=-1.3724e-03
# Epoch 1 step 4 starts
# Epoch 1 step 4: accepted, loss=-1.5139e-03
# Epoch 1 step 5 starts
# Epoch 1 step 5: accepted, loss=-1.6586e-03
# Epoch 1 step 6 starts
# Epoch 1 step 6: accepted, loss=-1.8207e-03
# Epoch 1 step 7 starts
# Epoch 1 step 7: accepted, loss=-2.0007e-03
# Epoch 1 step 8 starts
# Epoch 1 step 8: accepted, loss=-2.1968e-03
# Epoch 1 step 9 starts
# Epoch 1 step 9: accepted, loss=-2.3850e-03
# Epoch 1 step 10 starts
# Epoch 1 step 10: accepted, loss=-2.5787e-03
# Epoch 1 step 11 starts
# Epoch 1 step 11: accepted, loss=-2.7751e-03
# Epoch 1 step 12 starts
# Epoch 1 step 12: accepted, loss=-2.9589e-03
# Epoch 1 step 13 starts
# Epoch 1 step 13: accepted, loss=-3.1116e-03
# Epoch 1 step 14 starts
# Epoch 1 step 14: accepted, loss=-3.2233e-03
# Epoch 1 step 15 starts
# Epoch 1 step 15: accepted, loss=-3.3260e-03
# Epoch 1 step 16 starts
# Epoch 1 step 16: accepted, loss=-3.4240e-03
# Epoch 1 step 17 starts
# Epoch 1 step 17: accepted, loss=-3.5118e-03
# Epoch 1 step 18 starts
# Epoch 1 step 18: accepted, loss=-3.5896e-03
# Epoch 1 step 19 starts
# Epoch 1 step 19: accepted, loss=-3.7061e-03
# Epoch 1 step 20 starts
# Epoch 1 step 20: accepted, loss=-3.8500e-03
# → Epoch 1 done, avg per-step loss = -2.5671e-03
#
# Epoch 2 step 1 starts
# Epoch 2 step 1: accepted, loss=-1.0547e-02
# Epoch 2 step 2 starts
# Epoch 2 step 2: accepted, loss=-1.0416e-02
# Epoch 2 step 3 starts
# Epoch 2 step 3: accepted, loss=-1.0472e-02
# Epoch 2 step 4 starts
# Epoch 2 step 4: accepted, loss=-1.0620e-02
# Epoch 2 step 5 starts
# Epoch 2 step 5: accepted, loss=-1.0832e-02
# Epoch 2 step 6 starts
# Epoch 2 step 6: accepted, loss=-1.1065e-02
# Epoch 2 step 7 starts
# Epoch 2 step 7: accepted, loss=-1.1374e-02
# Epoch 2 step 8 starts
# Epoch 2 step 8: accepted, loss=-1.1729e-02
# Epoch 2 step 9 starts
# Epoch 2 step 9: accepted, loss=-1.1853e-02
# Epoch 2 step 10 starts
# Epoch 2 step 10: accepted, loss=-1.1943e-02
# Epoch 2 step 11 starts
# Epoch 2 step 11: accepted, loss=-1.1812e-02
# Epoch 2 step 12 starts
# Epoch 2 step 12: accepted, loss=-1.1473e-02
# Epoch 2 step 13 starts
# Epoch 2 step 13: accepted, loss=-1.0726e-02
# Epoch 2 step 14 starts
# Epoch 2 step 14: accepted, loss=-9.4716e-03
# Epoch 2 step 15 starts
# Epoch 2 step 15: accepted, loss=-7.7687e-03
# Epoch 2 step 16 starts
# Epoch 2 step 16: accepted, loss=-5.5008e-03
# Epoch 2 step 17 starts
# Epoch 2 step 17: accepted, loss=-3.7446e-03
# Epoch 2 step 18 starts
# Epoch 2 step 18: accepted, loss=-3.1089e-03
# Epoch 2 step 19 starts
# Epoch 2 step 19: accepted, loss=-2.5411e-03
# Epoch 2 step 20 starts
# Epoch 2 step 20: accepted, loss=-2.2319e-03
# → Epoch 2 done, avg per-step loss = -8.9615e-03
#
# Epoch 3 step 1 starts
# Epoch 3 step 1: accepted, loss=-2.1461e-03
# Epoch 3 step 2 starts
# Epoch 3 step 2: accepted, loss=-3.4426e-03
# Epoch 3 step 3 starts
# Epoch 3 step 3: accepted, loss=-6.5478e-03
# Epoch 3 step 4 starts
# Epoch 3 step 4: accepted, loss=-2.2232e-02
# Epoch 3 step 5 starts
# tensor(0.1255, device='cuda:0', grad_fn=<AbsBackward0>) tensor(438.9300, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=4.3893e+02
# tensor(0.7074, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.1243, device='cuda:0', grad_fn=<AbsBackward0>) tensor(438.5042, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=4.3850e+02
# tensor(0.7025, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.1225, device='cuda:0', grad_fn=<AbsBackward0>) tensor(437.9180, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=4.3792e+02
# tensor(0.6968, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.1205, device='cuda:0', grad_fn=<AbsBackward0>) tensor(437.2221, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=4.3722e+02
# tensor(0.6904, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.1183, device='cuda:0', grad_fn=<AbsBackward0>) tensor(436.4428, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=4.3644e+02
# tensor(0.6115, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0925, device='cuda:0', grad_fn=<AbsBackward0>) tensor(426.2229, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=4.2622e+02
# tensor(0.5161, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0656, device='cuda:0', grad_fn=<AbsBackward0>) tensor(412.1353, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=4.1214e+02
# tensor(0.2160, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0110, device='cuda:0', grad_fn=<AbsBackward0>) tensor(342.8280, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=3.4283e+02
# tensor(0.1142, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0029, device='cuda:0', grad_fn=<AbsBackward0>) tensor(295.1169, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 5: rejected, loss=2.9512e+02
# tensor(0.0328, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2553,  0.5763, -0.4859],
#         [ 0.6432,  0.2512, -1.1920],
#         [ 0.5595,  0.1869, -1.1897]], device='cuda:0', requires_grad=True) tensor([[ 0.5709, -0.7284, -1.4066],
#         [ 2.6378,  3.4250,  2.2882],
#         [-1.7069, -1.0161,  0.0924]], device='cuda:0', requires_grad=True) tensor(-1415723.7500, device='cuda:0') tensor([[ 1.5813e+01, -1.7754e+01, -3.3811e+01],
#         [-8.5508e+02, -6.4738e+02,  3.4285e+01],
#         [ 8.3927e+02,  6.6513e+02, -4.7467e-01]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 10.0375],
#         [464.5630],
#         [207.0633]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# Epoch 3 step 5: accepted, loss=-1.4636e-03
# Epoch 3 step 6 starts
# tensor(0.0028, device='cuda:0', grad_fn=<AbsBackward0>) tensor(294.5590, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.9456e+02
# tensor(0.1949, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0110, device='cuda:0', grad_fn=<AbsBackward0>) tensor(343.0058, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.4301e+02
# tensor(0.1818, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0095, device='cuda:0', grad_fn=<AbsBackward0>) tensor(337.4632, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.3746e+02
# tensor(0.0964, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0023, device='cuda:0', grad_fn=<AbsBackward0>) tensor(287.2005, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.8720e+02
# tensor(0.1103, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0031, device='cuda:0', grad_fn=<AbsBackward0>) tensor(297.9858, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.9799e+02
# tensor(0.0922, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0021, device='cuda:0', grad_fn=<AbsBackward0>) tensor(283.5354, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.8354e+02
# tensor(0.1513, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0064, device='cuda:0', grad_fn=<AbsBackward0>) tensor(322.9348, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.2293e+02
# tensor(0.1108, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0032, device='cuda:0', grad_fn=<AbsBackward0>) tensor(298.3442, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.9834e+02
# tensor(0.1237, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0041, device='cuda:0', grad_fn=<AbsBackward0>) tensor(307.0868, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.0709e+02
# tensor(0.2266, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0152, device='cuda:0', grad_fn=<AbsBackward0>) tensor(355.0299, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.5503e+02
# tensor(0.2559, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0197, device='cuda:0', grad_fn=<AbsBackward0>) tensor(364.8157, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.6482e+02
# tensor(0.2073, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0126, device='cuda:0', grad_fn=<AbsBackward0>) tensor(347.9180, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.4792e+02
# tensor(0.1080, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0030, device='cuda:0', grad_fn=<AbsBackward0>) tensor(296.3659, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.9637e+02
# tensor(0.1001, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0025, device='cuda:0', grad_fn=<AbsBackward0>) tensor(290.2386, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.9024e+02
# tensor(0.0803, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0014, device='cuda:0', grad_fn=<AbsBackward0>) tensor(271.4245, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.7142e+02
# tensor(0.1187, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0037, device='cuda:0', grad_fn=<AbsBackward0>) tensor(303.8467, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.0385e+02
# tensor(0.2497, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0187, device='cuda:0', grad_fn=<AbsBackward0>) tensor(362.8093, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.6281e+02
# tensor(0.3118, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0299, device='cuda:0', grad_fn=<AbsBackward0>) tensor(380.8235, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.8082e+02
# tensor(0.3217, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0319, device='cuda:0', grad_fn=<AbsBackward0>) tensor(383.3829, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.8338e+02
# tensor(0.2860, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0249, device='cuda:0', grad_fn=<AbsBackward0>) tensor(373.8133, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.7381e+02
# tensor(0.2044, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0122, device='cuda:0', grad_fn=<AbsBackward0>) tensor(346.7804, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.4678e+02
# tensor(0.0915, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0020, device='cuda:0', grad_fn=<AbsBackward0>) tensor(282.9783, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=2.8298e+02
# tensor(0.1187, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0037, device='cuda:0', grad_fn=<AbsBackward0>) tensor(303.8343, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.0383e+02
# tensor(0.1675, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0080, device='cuda:0', grad_fn=<AbsBackward0>) tensor(330.9680, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.3097e+02
# tensor(0.1336, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0048, device='cuda:0', grad_fn=<AbsBackward0>) tensor(313.1530, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 6: rejected, loss=3.1315e+02
# tensor(0.0589, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.2760,  0.5501, -0.5364],
#         [ 0.5309,  0.2130, -1.1091],
#         [ 0.5906,  0.2227, -1.1867]], device='cuda:0', requires_grad=True) tensor([[ 0.6967, -0.8696, -1.6756],
#         [-9.4918, -5.7583,  2.7745],
#         [ 3.6102,  3.1979,  0.0894]], device='cuda:0', requires_grad=True) tensor(-1415560.5000, device='cuda:0') tensor([[  20.1477,  -22.8651,  -42.8582],
#         [ 742.2315,  130.2858, -957.9837],
#         [-762.3792, -107.4207, 1000.8420]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[ 12.7710],
#         [527.6884],
#         [244.1572]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# Epoch 3 step 6: accepted, loss=-5.3477e-03
# Epoch 3 step 7 starts
# tensor(0.0024, device='cuda:0', grad_fn=<AbsBackward0>) tensor(289.1773, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.8918e+02
# tensor(0.4806, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0025, device='cuda:0', grad_fn=<AbsBackward0>) tensor(290.4565, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9046e+02
# tensor(0.4898, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0026, device='cuda:0', grad_fn=<AbsBackward0>) tensor(291.5079, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9151e+02
# tensor(0.4974, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0027, device='cuda:0', grad_fn=<AbsBackward0>) tensor(292.3680, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9237e+02
# tensor(0.5036, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0027, device='cuda:0', grad_fn=<AbsBackward0>) tensor(293.0662, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9307e+02
# tensor(0.5086, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0028, device='cuda:0', grad_fn=<AbsBackward0>) tensor(293.6267, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9363e+02
# tensor(0.5126, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0028, device='cuda:0', grad_fn=<AbsBackward0>) tensor(294.0641, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9406e+02
# tensor(0.5172, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0028, device='cuda:0', grad_fn=<AbsBackward0>) tensor(294.5775, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9458e+02
# tensor(0.5213, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0029, device='cuda:0', grad_fn=<AbsBackward0>) tensor(295.0197, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9502e+02
# tensor(0.5247, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0029, device='cuda:0', grad_fn=<AbsBackward0>) tensor(295.3886, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9539e+02
# tensor(0.5275, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0029, device='cuda:0', grad_fn=<AbsBackward0>) tensor(295.6910, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9569e+02
# tensor(0.5297, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0030, device='cuda:0', grad_fn=<AbsBackward0>) tensor(295.9270, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9593e+02
# tensor(0.5313, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
#         [-151.7254,   71.6563,  118.3426]], device='cuda:0') tensor([-0.3840, -0.3432, -0.0291], device='cuda:0', grad_fn=<SumBackward1>) tensor([[53.6352],
#         [ 9.2220],
#         [39.7023]], device='cuda:0') tensor([[4.1178],
#         [2.3098],
#         [5.1717]], device='cuda:0')
# tensor(0.0030, device='cuda:0', grad_fn=<AbsBackward0>) tensor(296.1044, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 3 step 7: rejected, loss=2.9610e+02
# tensor(0.5325, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[ 0.3256,  0.4892, -0.6532],
#         [ 0.5297, -0.0284, -1.6661],
#         [ 0.5474,  0.3751, -0.8452]], device='cuda:0', requires_grad=True) tensor([[  0.9852,  -1.1969,  -2.2891],
#         [  9.4499,  -2.4334, -21.6732],
#         [ -5.0792,   1.9735,  11.4967]], device='cuda:0', requires_grad=True) tensor(-1414620.8750, device='cuda:0') tensor([[ 152.7075,  -81.1413, -137.3900],
#         [  -0.9821,    9.4850,   19.0474],
# ...
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6758, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2977, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6757, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2925, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1229e+02
# tensor(0.6668, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6759, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.3044, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# tensor(0.6668, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6760, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.3077, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1231e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6759, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.3030, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6757, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2934, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1229e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6758, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2964, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6757, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2931, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1229e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6758, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2946, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1229e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6758, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2946, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1229e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6757, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2932, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1229e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6758, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2958, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6757, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2924, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1229e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6759, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.3029, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# tensor(0.6668, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6759, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.3048, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# tensor(0.6667, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-0.7047,  0.5561, -0.4842],
#         [-0.5470, -0.7479,  0.4108],
#         [-0.5435, -0.7935,  0.4444]], device='cuda:0', requires_grad=True) tensor([[-0.1014, -0.4966,  0.3247],
#         [-0.6580, -1.7956, -1.5570],
#         [ 0.6477,  3.1171,  1.6812]], device='cuda:0', requires_grad=True) tensor(-648208.8750, device='cuda:0') tensor([[ 5.9108e-01, -4.9108e+00,  3.3738e+00],
#         [ 8.8276e+01, -1.1614e+03,  8.5573e+02],
#         [-8.8867e+01,  1.1663e+03, -8.5910e+02]], device='cuda:0') tensor([-0.7892, -0.4101,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[  1.6784],
#         [579.6267],
#         [774.7797]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# tensor(0.6758, device='cuda:0', grad_fn=<AbsBackward0>) tensor(512.2991, device='cuda:0', grad_fn=<SumBackward0>) tensor(False, device='cuda:0')
# Epoch 10 step 19: rejected, loss=5.1230e+02
# Epoch 10 step 20 starts
# tensor(0.6974, device='cuda:0', grad_fn=<MeanBackward0>)
# tensor([[-7.3555e-01, -8.0976e-02, -5.7505e-02],
#         [ 6.8829e+00, -1.0546e+02,  7.5649e+01],
#         [-1.0656e+01,  1.3967e+02, -1.0037e+02]], device='cuda:0',
#        requires_grad=True) tensor([[ 9.0327e-03, -1.4144e+00,  9.5520e-01],
#         [ 2.2946e+01, -3.1233e+02,  2.2725e+02],
#         [-3.0984e+01,  4.1824e+02, -3.0411e+02]], device='cuda:0',
#        requires_grad=True) tensor(-210134.5312, device='cuda:0') tensor([[ 1.7902e-05, -2.4434e-04,  1.7564e-04],
#         [-3.3824e-05,  4.6830e-04, -3.3642e-04],
#         [ 1.5923e-05, -2.2397e-04,  1.6078e-04]], device='cuda:0') tensor([-0.7892, -0.4100,  0.4250], device='cuda:0', grad_fn=<SumBackward1>) tensor([[8.4500e-05],
#         [2.3165e-04],
#         [1.4743e-04]], device='cuda:0') tensor([[3.5674],
#         [2.4935],
#         [1.8731]], device='cuda:0')
# Epoch 10 step 20: accepted, loss=-6.6950e-01
# → Epoch 10 done, avg per-step loss = 2.5580e+01
