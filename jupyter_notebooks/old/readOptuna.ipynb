# %%
import os
import optuna
import shutil
from optuna.artifacts import FileSystemArtifactStore
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import TensorDataset, DataLoader, random_split
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("../src/")
import importlib
import structures
importlib.reload(structures)
from structures import *
import losses
importlib.reload(losses)
from losses import *
import trainer
importlib.reload(trainer)
from trainer import *
#dtype = torch.float32
dtype = torch.double
torch.set_default_dtype(dtype)
torch.autograd.set_detect_anomaly(True)
# Set the device to CUDA if available, otherwise CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

import deepspeed

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# Using device: cuda

# %% [markdown]
# ## Data load

# %%
#from src.trainer import num_samples

# Example unsupervised data: 100 samples with 10 features each
data = np.load("../data/three_body_train_data.npy")
num_samples = data.shape[0]
num_samples_start = int(data.shape[0]*0.8)
#num_samples_start = 0
num_samples_end   = data.shape[0]
num_samples = num_samples_end - num_samples_start
num_features = data.shape[1]

# Placeholder for input (magnitudes of velocities and accelerations)
data_org = torch.tensor(data[num_samples_start:num_samples_end,:], dtype=dtype).to(device)
data = torch.empty((num_samples,6+num_features), dtype=dtype).to(device)
data[:,6:] = data_org


# Magnitudes vel, acc, mass
vel = torch.norm(data_org[:,4:7], p=2, dim=1)
acc = torch.empty((num_samples,4), dtype=dtype).to(device)
acc[:,0] = torch.norm(data_org[:,7:10], p=2, dim=1)
acc[:,1] = torch.norm(data_org[:,10:13], p=2, dim=1)
acc[:,2] = torch.norm(data_org[:,13:16], p=2, dim=1)
acc[:,3] = torch.norm(data_org[:,16:19], p=2, dim=1)
mass = data_org[:,0]

data[:,0] = vel
data[:,1:5] = acc
data[:,5] = mass

# Normalize the data
data_min = data[:,:6].min(axis=0, keepdim=True).values
data_max = data[:,:6].max(axis=0, keepdim=True).values
data[:,:6] = (data[:,:6] - data_min) / (data_max - data_min)


# Wrap the feature tensor in a TensorDataset
# Each item from the dataset will be a tuple containing one tensor (X[i],)
dataset = TensorDataset(data)

# Define the proportion for the test set (e.g., 20%)
test_ratio = 0.2
num_test = int(num_samples * test_ratio)
num_train = num_samples - num_test

# Use random_split to split the dataset into train and test subsets
# Define generator with a fixed seed
generator = torch.Generator().manual_seed(42)
train_dataset, test_dataset = random_split(dataset, [num_train, num_test], generator=generator)

# Create DataLoaders for the training and testing datasets
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
print(data.shape)
# Out:
# torch.Size([15586, 68])

# %% [markdown]
# ## Model load

# %%
input_size = 6     # Number of input features
input_mask = np.r_[0:6]
hidden_dims = [32,64,64,32] 
output_size = 2     # Number of output 
batch_size=64
TargetEnergyError =1e-2
# Load an existing study from your storage (e.g., SQLite)
study = optuna.load_study(
    study_name="three_body_preliminary",
    storage="sqlite:///../optuna/database/three_body_preliminary.db"
)

# Retrieve the trial (here we choose trial number 1, adjust as needed)
trial = next(t for t in study.trials if t.number == 576)
artifact_base_path = "../data/optuna/artifacts/"
file_path = artifact_base_path+f"/model_trial_{trial.number}.pt"

weights = {"time_step":0.1, "energy_loss":1e-1}

# Instantiate the model
model = FullyConnectedNN(input_dim=input_size, output_dim=output_size, hidden_dims=hidden_dims, activation='relu', dropout=0.1, output_positive=True).to(device)

# Load the state dictionary from a file
state_dict = torch.load(file_path, map_location=torch.device(device))
model.load_state_dict(state_dict)

# Set the model to evaluation mode (important for inference)
model.eval()

# Define the loss function (CrossEntropyLoss is common for classification tasks)
criterion = CustomizableLoss3DM(nParticle=3, nAttribute=20, nBatch=batch_size,alpha=0.1, beta=1.0, gamma=1.0, TargetEnergyError=TargetEnergyError,
                            data_min=data_min, data_max=data_max,device=device)


test_loss, energy_error, energy_error_std, energy_error_fiducial, energy_error_fiducial_std, energy_pred, energy_init, time_step, time_step_fiducial = \
    validate(model, criterion, test_loader, input_mask, weights, device)
print(f"Test Loss: {test_loss:.4e}, Energy Loss: {energy_error:.4e}/{energy_error_fiducial:.4e}, std: {energy_error_std:.4e}/{energy_error_fiducial_std:.4e}, Time step: {time_step:.4e}/{time_step_fiducial:.4e}")

cpath = artifact_base_path + f"cmodel_trial_{trial.number}.pt"
if os.path.exists(cpath):
    print("traced model exists.")
else:
    traced_model = torch.jit.script(model)
    traced_model.save(cpath)
# Out:
# Test Loss: 2.5099e+02, Energy Loss: 1.5071e+06/5.9096e-03, std: 3.5494e+07/1.9795e-01, Time step: 2.8580e-08/1.0262e-09

# %%
18/287/49/50/412/337

# %%
study.best_trials
# Out:
# [FrozenTrial(number=3, state=TrialState.COMPLETE, values=[6010.943933357334, 0.016313339423413512], datetime_start=datetime.datetime(2025, 3, 24, 21, 25, 37, 105252), datetime_complete=datetime.datetime(2025, 3, 24, 21, 28, 36, 866095), params={'optimizer': 'SGD', 'lr': 1.9142976961696882e-07}, user_attrs={'artifact_id': 'b709429e-57ac-41f9-950d-05c2744d7d42'}, system_attrs={'artifacts:b709429e-57ac-41f9-950d-05c2744d7d42': '{"artifact_id": "b709429e-57ac-41f9-950d-05c2744d7d42", "filename": "model_trial_3.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=4, value=None),
#  FrozenTrial(number=5, state=TrialState.COMPLETE, values=[6240.613105477894, 0.024051328635629952], datetime_start=datetime.datetime(2025, 3, 24, 21, 25, 47, 991052), datetime_complete=datetime.datetime(2025, 3, 24, 21, 28, 52, 233115), params={'optimizer': 'RMSprop', 'lr': 7.786019401103665e-07}, user_attrs={'artifact_id': '0f642ff8-d8f7-4775-82e1-dc55a246ccd0'}, system_attrs={'artifacts:0f642ff8-d8f7-4775-82e1-dc55a246ccd0': '{"artifact_id": "0f642ff8-d8f7-4775-82e1-dc55a246ccd0", "filename": "model_trial_5.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=6, value=None),
#  FrozenTrial(number=6, state=TrialState.COMPLETE, values=[64.9238169213806, 2.9951069379188893e-09], datetime_start=datetime.datetime(2025, 3, 24, 21, 28, 36, 918084), datetime_complete=datetime.datetime(2025, 3, 24, 21, 31, 33, 33423), params={'optimizer': 'Adam', 'lr': 5.247335607566404e-05}, user_attrs={'artifact_id': '94263c91-178d-44b0-99a2-9115c3b68613'}, system_attrs={'artifacts:94263c91-178d-44b0-99a2-9115c3b68613': '{"artifact_id": "94263c91-178d-44b0-99a2-9115c3b68613", "filename": "model_trial_6.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=7, value=None),
#  FrozenTrial(number=7, state=TrialState.COMPLETE, values=[6171.82957528581, 0.020555215641845197], datetime_start=datetime.datetime(2025, 3, 24, 21, 28, 37, 812549), datetime_complete=datetime.datetime(2025, 3, 24, 21, 31, 32, 612346), params={'optimizer': 'RMSprop', 'lr': 1.8544594222511806e-06}, user_attrs={'artifact_id': 'ef134daa-9a7c-4fff-9507-bd6c1c3caaf1'}, system_attrs={'artifacts:ef134daa-9a7c-4fff-9507-bd6c1c3caaf1': '{"artifact_id": "ef134daa-9a7c-4fff-9507-bd6c1c3caaf1", "filename": "model_trial_7.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=8, value=None),
#  FrozenTrial(number=17, state=TrialState.COMPLETE, values=[6315.014181604722, 0.02482653293113396], datetime_start=datetime.datetime(2025, 3, 24, 21, 31, 50, 661339), datetime_complete=datetime.datetime(2025, 3, 24, 21, 34, 49, 814049), params={'optimizer': 'SGD', 'lr': 1.3078980043199441e-09}, user_attrs={'artifact_id': '03a47335-3803-494a-8636-0ed567549172'}, system_attrs={'artifacts:03a47335-3803-494a-8636-0ed567549172': '{"artifact_id": "03a47335-3803-494a-8636-0ed567549172", "filename": "model_trial_17.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=18, value=None),
#  FrozenTrial(number=18, state=TrialState.COMPLETE, values=[19.35207402317904, 4.463317597468952e-10], datetime_start=datetime.datetime(2025, 3, 24, 21, 34, 28, 630785), datetime_complete=datetime.datetime(2025, 3, 24, 21, 37, 22, 420981), params={'optimizer': 'SGD', 'lr': 9.634783544381163e-06}, user_attrs={'artifact_id': 'bf744f12-949c-42f1-8eea-795369959063'}, system_attrs={'artifacts:bf744f12-949c-42f1-8eea-795369959063': '{"artifact_id": "bf744f12-949c-42f1-8eea-795369959063", "filename": "model_trial_18.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=19, value=None),
#  FrozenTrial(number=21, state=TrialState.COMPLETE, values=[5742.880341785534, 0.011306671251556046], datetime_start=datetime.datetime(2025, 3, 24, 21, 34, 32, 746704), datetime_complete=datetime.datetime(2025, 3, 24, 21, 37, 28, 967419), params={'optimizer': 'RMSprop', 'lr': 1.3233600260505884e-05}, user_attrs={'artifact_id': 'f61423c8-e8a6-4c4f-8ae5-f3b6b693b137'}, system_attrs={'artifacts:f61423c8-e8a6-4c4f-8ae5-f3b6b693b137': '{"artifact_id": "f61423c8-e8a6-4c4f-8ae5-f3b6b693b137", "filename": "model_trial_21.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=22, value=None),
#  FrozenTrial(number=22, state=TrialState.COMPLETE, values=[3892.614129804617, 0.0007978226765670805], datetime_start=datetime.datetime(2025, 3, 24, 21, 34, 45, 46326), datetime_complete=datetime.datetime(2025, 3, 24, 21, 37, 46, 410941), params={'optimizer': 'RMSprop', 'lr': 2.0990381734966795e-05}, user_attrs={'artifact_id': '3b69832c-2944-48e1-ba3a-d4ad62807876'}, system_attrs={'artifacts:3b69832c-2944-48e1-ba3a-d4ad62807876': '{"artifact_id": "3b69832c-2944-48e1-ba3a-d4ad62807876", "filename": "model_trial_22.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=23, value=None),
#  FrozenTrial(number=25, state=TrialState.COMPLETE, values=[6001.398281531094, 0.015365739887957123], datetime_start=datetime.datetime(2025, 3, 24, 21, 37, 25, 372176), datetime_complete=datetime.datetime(2025, 3, 24, 21, 40, 21, 286386), params={'optimizer': 'RMSprop', 'lr': 1.1584901087311122e-05}, user_attrs={'artifact_id': 'adc648ee-249b-4425-a63d-2078bd0353ee'}, system_attrs={'artifacts:adc648ee-249b-4425-a63d-2078bd0353ee': '{"artifact_id": "adc648ee-249b-4425-a63d-2078bd0353ee", "filename": "model_trial_25.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=26, value=None),
#  FrozenTrial(number=27, state=TrialState.COMPLETE, values=[698.6744704924256, 6.398272760058281e-07], datetime_start=datetime.datetime(2025, 3, 24, 21, 37, 29, 24360), datetime_complete=datetime.datetime(2025, 3, 24, 21, 40, 25, 645469), params={'optimizer': 'RMSprop', 'lr': 2.809445914838945e-05}, user_attrs={'artifact_id': '9d4d2aae-1a45-4b2e-bc7b-f039b70ba79b'}, system_attrs={'artifacts:9d4d2aae-1a45-4b2e-bc7b-f039b70ba79b': '{"artifact_id": "9d4d2aae-1a45-4b2e-bc7b-f039b70ba79b", "filename": "model_trial_27.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=28, value=None),
#  FrozenTrial(number=31, state=TrialState.COMPLETE, values=[6147.610598985009, 0.02020982589617939], datetime_start=datetime.datetime(2025, 3, 24, 21, 40, 21, 346930), datetime_complete=datetime.datetime(2025, 3, 24, 21, 43, 16, 366699), params={'optimizer': 'RMSprop', 'lr': 1.4571728626286603e-06}, user_attrs={'artifact_id': '443544bc-9921-4833-bdea-86417a76dd87'}, system_attrs={'artifacts:443544bc-9921-4833-bdea-86417a76dd87': '{"artifact_id": "443544bc-9921-4833-bdea-86417a76dd87", "filename": "model_trial_31.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=32, value=None),
#  FrozenTrial(number=49, state=TrialState.COMPLETE, values=[48.67257092241124, 1.9184417509132367e-09], datetime_start=datetime.datetime(2025, 3, 24, 21, 49, 9, 396875), datetime_complete=datetime.datetime(2025, 3, 24, 21, 52, 11, 804630), params={'optimizer': 'Adam', 'lr': 4.990346012054198e-05}, user_attrs={'artifact_id': '8a78b5ba-8be3-421c-94e1-8ad7e5907b2e'}, system_attrs={'artifacts:8a78b5ba-8be3-421c-94e1-8ad7e5907b2e': '{"artifact_id": "8a78b5ba-8be3-421c-94e1-8ad7e5907b2e", "filename": "model_trial_49.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=50, value=None),
#  FrozenTrial(number=50, state=TrialState.COMPLETE, values=[38.59336285923367, 5.2566074224045e-10], datetime_start=datetime.datetime(2025, 3, 24, 21, 49, 13, 458770), datetime_complete=datetime.datetime(2025, 3, 24, 21, 52, 16, 272170), params={'optimizer': 'Adam', 'lr': 5.9229160151869656e-05}, user_attrs={'artifact_id': '7e91f45e-44a3-421c-82cc-66fad793d74e'}, system_attrs={'artifacts:7e91f45e-44a3-421c-82cc-66fad793d74e': '{"artifact_id": "7e91f45e-44a3-421c-82cc-66fad793d74e", "filename": "model_trial_50.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=51, value=None),
#  FrozenTrial(number=61, state=TrialState.COMPLETE, values=[6144.667478391273, 0.020184667491400864], datetime_start=datetime.datetime(2025, 3, 24, 21, 55, 8, 561890), datetime_complete=datetime.datetime(2025, 3, 24, 21, 58, 5, 692711), params={'optimizer': 'SGD', 'lr': 1.1087092431586249e-09}, user_attrs={'artifact_id': '0eab69c9-2edc-417b-aab2-840f71537038'}, system_attrs={'artifacts:0eab69c9-2edc-417b-aab2-840f71537038': '{"artifact_id": "0eab69c9-2edc-417b-aab2-840f71537038", "filename": "model_trial_61.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=62, value=None),
#  FrozenTrial(number=66, state=TrialState.COMPLETE, values=[6021.899373801372, 0.01654899452741893], datetime_start=datetime.datetime(2025, 3, 24, 21, 57, 45, 821764), datetime_complete=datetime.datetime(2025, 3, 24, 22, 0, 38, 862033), params={'optimizer': 'SGD', 'lr': 1.7125152628341935e-07}, user_attrs={'artifact_id': '011684d4-e441-4cd7-b336-9b813bb8638c'}, system_attrs={'artifacts:011684d4-e441-4cd7-b336-9b813bb8638c': '{"artifact_id": "011684d4-e441-4cd7-b336-9b813bb8638c", "filename": "model_trial_66.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=67, value=None),
#  FrozenTrial(number=90, state=TrialState.COMPLETE, values=[5788.260322770667, 0.011805797311442974], datetime_start=datetime.datetime(2025, 3, 24, 22, 9, 16, 557143), datetime_complete=datetime.datetime(2025, 3, 24, 22, 12, 7, 589643), params={'optimizer': 'SGD', 'lr': 5.280207443277026e-07}, user_attrs={'artifact_id': 'e12fb129-3d82-4cc4-8a53-67bb6f83caae'}, system_attrs={'artifacts:e12fb129-3d82-4cc4-8a53-67bb6f83caae': '{"artifact_id": "e12fb129-3d82-4cc4-8a53-67bb6f83caae", "filename": "model_trial_90.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=91, value=None),
#  FrozenTrial(number=94, state=TrialState.COMPLETE, values=[5673.211147632674, 0.009703061314141457], datetime_start=datetime.datetime(2025, 3, 24, 22, 10, 34, 44799), datetime_complete=datetime.datetime(2025, 3, 24, 22, 13, 30, 807566), params={'optimizer': 'SGD', 'lr': 6.057585536435071e-07}, user_attrs={'artifact_id': '80a697e1-ca9b-45c7-88da-29365d6344c0'}, system_attrs={'artifacts:80a697e1-ca9b-45c7-88da-29365d6344c0': '{"artifact_id": "80a697e1-ca9b-45c7-88da-29365d6344c0", "filename": "model_trial_94.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=95, value=None),
#  FrozenTrial(number=95, state=TrialState.COMPLETE, values=[5652.909901395912, 0.009282841317629983], datetime_start=datetime.datetime(2025, 3, 24, 22, 11, 2, 822537), datetime_complete=datetime.datetime(2025, 3, 24, 22, 14, 4, 852563), params={'optimizer': 'SGD', 'lr': 6.263275785560394e-07}, user_attrs={'artifact_id': 'e341103e-d060-4496-a496-6ab0667696ca'}, system_attrs={'artifacts:e341103e-d060-4496-a496-6ab0667696ca': '{"artifact_id": "e341103e-d060-4496-a496-6ab0667696ca", "filename": "model_trial_95.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=96, value=None),
#  FrozenTrial(number=111, state=TrialState.COMPLETE, values=[5976.478331938383, 0.015185869505122506], datetime_start=datetime.datetime(2025, 3, 24, 22, 18, 56, 458876), datetime_complete=datetime.datetime(2025, 3, 24, 22, 21, 52, 787236), params={'optimizer': 'SGD', 'lr': 2.884806948211116e-07}, user_attrs={'artifact_id': 'c0de5c8b-d068-46ae-bc67-21fc596a5b5a'}, system_attrs={'artifacts:c0de5c8b-d068-46ae-bc67-21fc596a5b5a': '{"artifact_id": "c0de5c8b-d068-46ae-bc67-21fc596a5b5a", "filename": "model_trial_111.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=112, value=None),
#  FrozenTrial(number=120, state=TrialState.COMPLETE, values=[5244.031155376789, 0.005080135397036591], datetime_start=datetime.datetime(2025, 3, 24, 22, 23, 48, 136829), datetime_complete=datetime.datetime(2025, 3, 24, 22, 26, 39, 943877), params={'optimizer': 'SGD', 'lr': 8.672403584875543e-07}, user_attrs={'artifact_id': '902de256-49e3-49c4-bb63-83de50d171f6'}, system_attrs={'artifacts:902de256-49e3-49c4-bb63-83de50d171f6': '{"artifact_id": "902de256-49e3-49c4-bb63-83de50d171f6", "filename": "model_trial_120.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=121, value=None),
#  FrozenTrial(number=123, state=TrialState.COMPLETE, values=[5703.670503767491, 0.01009809133373791], datetime_start=datetime.datetime(2025, 3, 24, 22, 24, 48, 98210), datetime_complete=datetime.datetime(2025, 3, 24, 22, 27, 43, 379310), params={'optimizer': 'SGD', 'lr': 7.466578209083943e-07}, user_attrs={'artifact_id': 'f885e5d8-782a-435c-9247-9f584eea38ca'}, system_attrs={'artifacts:f885e5d8-782a-435c-9247-9f584eea38ca': '{"artifact_id": "f885e5d8-782a-435c-9247-9f584eea38ca", "filename": "model_trial_123.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=124, value=None),
#  FrozenTrial(number=126, state=TrialState.COMPLETE, values=[133.55929491374008, 1.240023614810289e-08], datetime_start=datetime.datetime(2025, 3, 24, 22, 26, 39, 984407), datetime_complete=datetime.datetime(2025, 3, 24, 22, 29, 31, 474285), params={'optimizer': 'RMSprop', 'lr': 3.910514992594646e-05}, user_attrs={'artifact_id': '52beb970-8baa-4756-abd5-da11362abd6d'}, system_attrs={'artifacts:52beb970-8baa-4756-abd5-da11362abd6d': '{"artifact_id": "52beb970-8baa-4756-abd5-da11362abd6d", "filename": "model_trial_126.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=127, value=None),
#  FrozenTrial(number=129, state=TrialState.COMPLETE, values=[349.7840594369797, 6.852425715705213e-08], datetime_start=datetime.datetime(2025, 3, 24, 22, 27, 43, 421331), datetime_complete=datetime.datetime(2025, 3, 24, 22, 30, 38, 555937), params={'optimizer': 'RMSprop', 'lr': 3.7479155547861475e-05}, user_attrs={'artifact_id': 'b459f3b9-c2f2-4d4c-b218-286cfaf66337'}, system_attrs={'artifacts:b459f3b9-c2f2-4d4c-b218-286cfaf66337': '{"artifact_id": "b459f3b9-c2f2-4d4c-b218-286cfaf66337", "filename": "model_trial_129.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=130, value=None),
#  FrozenTrial(number=143, state=TrialState.COMPLETE, values=[6174.564439086396, 0.020763091558985487], datetime_start=datetime.datetime(2025, 3, 24, 22, 35, 14, 872939), datetime_complete=datetime.datetime(2025, 3, 24, 22, 38, 8, 680381), params={'optimizer': 'SGD', 'lr': 3.2516655700765267e-09}, user_attrs={'artifact_id': '191c91a6-c630-475c-83ba-7a7b486aa2c9'}, system_attrs={'artifacts:191c91a6-c630-475c-83ba-7a7b486aa2c9': '{"artifact_id": "191c91a6-c630-475c-83ba-7a7b486aa2c9", "filename": "model_trial_143.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=144, value=None),
#  FrozenTrial(number=168, state=TrialState.COMPLETE, values=[5980.546787938704, 0.015309505272151816], datetime_start=datetime.datetime(2025, 3, 24, 22, 47, 33, 554580), datetime_complete=datetime.datetime(2025, 3, 24, 22, 50, 35, 507325), params={'optimizer': 'SGD', 'lr': 4.341288375163107e-07}, user_attrs={'artifact_id': '20897087-3f41-4a53-ba7a-5a4f146a9923'}, system_attrs={'artifacts:20897087-3f41-4a53-ba7a-5a4f146a9923': '{"artifact_id": "20897087-3f41-4a53-ba7a-5a4f146a9923", "filename": "model_trial_168.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=169, value=None),
#  FrozenTrial(number=169, state=TrialState.COMPLETE, values=[5970.521258774404, 0.014971855160489291], datetime_start=datetime.datetime(2025, 3, 24, 22, 48, 8, 298198), datetime_complete=datetime.datetime(2025, 3, 24, 22, 51, 4, 96082), params={'optimizer': 'SGD', 'lr': 4.297246520100308e-07}, user_attrs={'artifact_id': 'a8b59ad7-e5e3-4ebb-b099-012230bf7614'}, system_attrs={'artifacts:a8b59ad7-e5e3-4ebb-b099-012230bf7614': '{"artifact_id": "a8b59ad7-e5e3-4ebb-b099-012230bf7614", "filename": "model_trial_169.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=170, value=None),
#  FrozenTrial(number=172, state=TrialState.COMPLETE, values=[5297.092013683618, 0.005994771160822211], datetime_start=datetime.datetime(2025, 3, 24, 22, 49, 5, 751784), datetime_complete=datetime.datetime(2025, 3, 24, 22, 52, 4, 529959), params={'optimizer': 'Adam', 'lr': 1.1909621668404288e-05}, user_attrs={'artifact_id': '51d65494-9128-48fc-a5c0-10510f72b7b7'}, system_attrs={'artifacts:51d65494-9128-48fc-a5c0-10510f72b7b7': '{"artifact_id": "51d65494-9128-48fc-a5c0-10510f72b7b7", "filename": "model_trial_172.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=173, value=None),
#  FrozenTrial(number=173, state=TrialState.COMPLETE, values=[6191.928294956585, 0.020922859689397926], datetime_start=datetime.datetime(2025, 3, 24, 22, 49, 48, 23427), datetime_complete=datetime.datetime(2025, 3, 24, 22, 52, 43, 1909), params={'optimizer': 'Adam', 'lr': 4.342503860924283e-07}, user_attrs={'artifact_id': 'eef6829f-fcf6-4a2d-9bf5-62e7e2acf139'}, system_attrs={'artifacts:eef6829f-fcf6-4a2d-9bf5-62e7e2acf139': '{"artifact_id": "eef6829f-fcf6-4a2d-9bf5-62e7e2acf139", "filename": "model_trial_173.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=174, value=None),
#  FrozenTrial(number=178, state=TrialState.COMPLETE, values=[5130.356464752358, 0.004515662992205804], datetime_start=datetime.datetime(2025, 3, 24, 22, 52, 4, 569099), datetime_complete=datetime.datetime(2025, 3, 24, 22, 55, 3, 802103), params={'optimizer': 'Adam', 'lr': 1.3157640301427415e-05}, user_attrs={'artifact_id': 'a2c8619a-e210-4855-9407-18b3787c90e6'}, system_attrs={'artifacts:a2c8619a-e210-4855-9407-18b3787c90e6': '{"artifact_id": "a2c8619a-e210-4855-9407-18b3787c90e6", "filename": "model_trial_178.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=179, value=None),
#  FrozenTrial(number=179, state=TrialState.COMPLETE, values=[4927.878957009894, 0.0035370649163560964], datetime_start=datetime.datetime(2025, 3, 24, 22, 52, 43, 37705), datetime_complete=datetime.datetime(2025, 3, 24, 22, 55, 37, 821546), params={'optimizer': 'Adam', 'lr': 1.3776853591352788e-05}, user_attrs={'artifact_id': 'e90a848d-2b6b-49ef-a26a-930b2c7fab8d'}, system_attrs={'artifacts:e90a848d-2b6b-49ef-a26a-930b2c7fab8d': '{"artifact_id": "e90a848d-2b6b-49ef-a26a-930b2c7fab8d", "filename": "model_trial_179.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=180, value=None),
#  FrozenTrial(number=181, state=TrialState.COMPLETE, values=[3493.7547747012645, 0.00038720625495165144], datetime_start=datetime.datetime(2025, 3, 24, 22, 54, 2, 156615), datetime_complete=datetime.datetime(2025, 3, 24, 22, 56, 59, 640085), params={'optimizer': 'Adam', 'lr': 1.7543225015390023e-05}, user_attrs={'artifact_id': '607a57f5-3b2c-4d8a-af2a-db162ce2bb7a'}, system_attrs={'artifacts:607a57f5-3b2c-4d8a-af2a-db162ce2bb7a': '{"artifact_id": "607a57f5-3b2c-4d8a-af2a-db162ce2bb7a", "filename": "model_trial_181.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=182, value=None),
#  FrozenTrial(number=183, state=TrialState.COMPLETE, values=[3415.126475140382, 0.0003551723580707649], datetime_start=datetime.datetime(2025, 3, 24, 22, 54, 20, 967233), datetime_complete=datetime.datetime(2025, 3, 24, 22, 57, 19, 666138), params={'optimizer': 'Adam', 'lr': 1.405446354895318e-05}, user_attrs={'artifact_id': '1b22622d-459e-47d4-a24a-ec90afe99671'}, system_attrs={'artifacts:1b22622d-459e-47d4-a24a-ec90afe99671': '{"artifact_id": "1b22622d-459e-47d4-a24a-ec90afe99671", "filename": "model_trial_183.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=184, value=None),
#  FrozenTrial(number=184, state=TrialState.COMPLETE, values=[5600.320728578627, 0.009090346417994164], datetime_start=datetime.datetime(2025, 3, 24, 22, 55, 3, 841231), datetime_complete=datetime.datetime(2025, 3, 24, 22, 58, 2, 800248), params={'optimizer': 'Adam', 'lr': 1.0725928306453544e-05}, user_attrs={'artifact_id': 'e66e3568-9a60-4a90-bc5d-513dca93b3fe'}, system_attrs={'artifacts:e66e3568-9a60-4a90-bc5d-513dca93b3fe': '{"artifact_id": "e66e3568-9a60-4a90-bc5d-513dca93b3fe", "filename": "model_trial_184.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=185, value=None),
#  FrozenTrial(number=187, state=TrialState.COMPLETE, values=[5101.470761822788, 0.003970453384917073], datetime_start=datetime.datetime(2025, 3, 24, 22, 56, 59, 689777), datetime_complete=datetime.datetime(2025, 3, 24, 22, 59, 56, 280307), params={'optimizer': 'Adam', 'lr': 1.284524835794216e-05}, user_attrs={'artifact_id': '63b2a1d8-1a15-4e89-ac52-7446c66ca9f1'}, system_attrs={'artifacts:63b2a1d8-1a15-4e89-ac52-7446c66ca9f1': '{"artifact_id": "63b2a1d8-1a15-4e89-ac52-7446c66ca9f1", "filename": "model_trial_187.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=188, value=None),
#  FrozenTrial(number=190, state=TrialState.COMPLETE, values=[4746.228104613566, 0.002420887844671935], datetime_start=datetime.datetime(2025, 3, 24, 22, 58, 2, 845543), datetime_complete=datetime.datetime(2025, 3, 24, 23, 1, 1, 379889), params={'optimizer': 'Adam', 'lr': 1.3773715023628414e-05}, user_attrs={'artifact_id': '9706ff85-7d67-4bf1-b7c3-e559ff59084a'}, system_attrs={'artifacts:9706ff85-7d67-4bf1-b7c3-e559ff59084a': '{"artifact_id": "9706ff85-7d67-4bf1-b7c3-e559ff59084a", "filename": "model_trial_190.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=191, value=None),
#  FrozenTrial(number=192, state=TrialState.COMPLETE, values=[6192.105376473764, 0.02123883228015592], datetime_start=datetime.datetime(2025, 3, 24, 22, 59, 47, 75215), datetime_complete=datetime.datetime(2025, 3, 24, 23, 2, 49, 852191), params={'optimizer': 'Adam', 'lr': 6.641795598977387e-06}, user_attrs={'artifact_id': 'be069331-3a24-4964-9a54-a85b16d03103'}, system_attrs={'artifacts:be069331-3a24-4964-9a54-a85b16d03103': '{"artifact_id": "be069331-3a24-4964-9a54-a85b16d03103", "filename": "model_trial_192.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=193, value=None),
#  FrozenTrial(number=203, state=TrialState.COMPLETE, values=[203.26085907956337, 1.9605029040304946e-08], datetime_start=datetime.datetime(2025, 3, 24, 23, 4, 20, 834069), datetime_complete=datetime.datetime(2025, 3, 24, 23, 7, 13, 421622), params={'optimizer': 'Adam', 'lr': 2.6290323042549935e-05}, user_attrs={'artifact_id': 'fc2c764c-fa4b-431b-a683-dd52e177b201'}, system_attrs={'artifacts:fc2c764c-fa4b-431b-a683-dd52e177b201': '{"artifact_id": "fc2c764c-fa4b-431b-a683-dd52e177b201", "filename": "model_trial_203.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=204, value=None),
#  FrozenTrial(number=204, state=TrialState.COMPLETE, values=[5784.451520825205, 0.01156556324056975], datetime_start=datetime.datetime(2025, 3, 24, 23, 5, 47, 448305), datetime_complete=datetime.datetime(2025, 3, 24, 23, 8, 42, 309053), params={'optimizer': 'Adam', 'lr': 9.084711031043622e-06}, user_attrs={'artifact_id': 'a222ad51-f917-4c3c-bc78-efad9df035f1'}, system_attrs={'artifacts:a222ad51-f917-4c3c-bc78-efad9df035f1': '{"artifact_id": "a222ad51-f917-4c3c-bc78-efad9df035f1", "filename": "model_trial_204.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=205, value=None),
#  FrozenTrial(number=207, state=TrialState.COMPLETE, values=[5809.4398315441695, 0.01206588352695558], datetime_start=datetime.datetime(2025, 3, 24, 23, 6, 11, 597493), datetime_complete=datetime.datetime(2025, 3, 24, 23, 9, 7, 28896), params={'optimizer': 'Adam', 'lr': 9.929944287229843e-06}, user_attrs={'artifact_id': 'fe1e08a2-ac8d-4874-8a26-327d8d2577bf'}, system_attrs={'artifacts:fe1e08a2-ac8d-4874-8a26-327d8d2577bf': '{"artifact_id": "fe1e08a2-ac8d-4874-8a26-327d8d2577bf", "filename": "model_trial_207.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=208, value=None),
#  FrozenTrial(number=209, state=TrialState.COMPLETE, values=[5676.986145181421, 0.009748805662043461], datetime_start=datetime.datetime(2025, 3, 24, 23, 7, 13, 475513), datetime_complete=datetime.datetime(2025, 3, 24, 23, 10, 6, 25710), params={'optimizer': 'Adam', 'lr': 1.1028860378220224e-05}, user_attrs={'artifact_id': '725cfeaf-75a5-4462-8da4-50f1f99030e6'}, system_attrs={'artifacts:725cfeaf-75a5-4462-8da4-50f1f99030e6': '{"artifact_id": "725cfeaf-75a5-4462-8da4-50f1f99030e6", "filename": "model_trial_209.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=210, value=None),
#  FrozenTrial(number=210, state=TrialState.COMPLETE, values=[5966.8042784890895, 0.0145590959135341], datetime_start=datetime.datetime(2025, 3, 24, 23, 8, 42, 361411), datetime_complete=datetime.datetime(2025, 3, 24, 23, 11, 37, 109143), params={'optimizer': 'Adam', 'lr': 1.1392158621747951e-05}, user_attrs={'artifact_id': '247dc50a-d6e5-43e7-9e70-45c8d1b5f744'}, system_attrs={'artifacts:247dc50a-d6e5-43e7-9e70-45c8d1b5f744': '{"artifact_id": "247dc50a-d6e5-43e7-9e70-45c8d1b5f744", "filename": "model_trial_210.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=211, value=None),
#  FrozenTrial(number=211, state=TrialState.COMPLETE, values=[3901.327709577299, 0.0009204162982436957], datetime_start=datetime.datetime(2025, 3, 24, 23, 8, 47, 772801), datetime_complete=datetime.datetime(2025, 3, 24, 23, 11, 46, 602406), params={'optimizer': 'Adam', 'lr': 1.647035487401216e-05}, user_attrs={'artifact_id': 'c2481153-5590-4f10-a968-c4aa5649f01f'}, system_attrs={'artifacts:c2481153-5590-4f10-a968-c4aa5649f01f': '{"artifact_id": "c2481153-5590-4f10-a968-c4aa5649f01f", "filename": "model_trial_211.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=212, value=None),
#  FrozenTrial(number=212, state=TrialState.COMPLETE, values=[3129.1923403057776, 0.00015936002852182313], datetime_start=datetime.datetime(2025, 3, 24, 23, 8, 51, 127851), datetime_complete=datetime.datetime(2025, 3, 24, 23, 11, 46, 52009), params={'optimizer': 'Adam', 'lr': 1.7898725430982216e-05}, user_attrs={'artifact_id': '5c87ec05-ad3b-4ac4-b8c7-5cf97c8051e6'}, system_attrs={'artifacts:5c87ec05-ad3b-4ac4-b8c7-5cf97c8051e6': '{"artifact_id": "5c87ec05-ad3b-4ac4-b8c7-5cf97c8051e6", "filename": "model_trial_212.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=213, value=None),
#  FrozenTrial(number=214, state=TrialState.COMPLETE, values=[3146.741548321419, 0.00022199043930589394], datetime_start=datetime.datetime(2025, 3, 24, 23, 9, 53, 506036), datetime_complete=datetime.datetime(2025, 3, 24, 23, 12, 50, 441267), params={'optimizer': 'Adam', 'lr': 1.640725754068449e-05}, user_attrs={'artifact_id': '70997ad9-941c-49f5-8790-291df5c80765'}, system_attrs={'artifacts:70997ad9-941c-49f5-8790-291df5c80765': '{"artifact_id": "70997ad9-941c-49f5-8790-291df5c80765", "filename": "model_trial_214.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=215, value=None),
#  FrozenTrial(number=216, state=TrialState.COMPLETE, values=[1427.80060453624, 4.6129457562011245e-06], datetime_start=datetime.datetime(2025, 3, 24, 23, 11, 37, 158131), datetime_complete=datetime.datetime(2025, 3, 24, 23, 14, 31, 790476), params={'optimizer': 'Adam', 'lr': 1.781227169049275e-05}, user_attrs={'artifact_id': '3c7484ad-501f-4f7f-8b7d-6aa4dfe7b050'}, system_attrs={'artifacts:3c7484ad-501f-4f7f-8b7d-6aa4dfe7b050': '{"artifact_id": "3c7484ad-501f-4f7f-8b7d-6aa4dfe7b050", "filename": "model_trial_216.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=217, value=None),
#  FrozenTrial(number=217, state=TrialState.COMPLETE, values=[4416.651896151646, 0.0018683529686712903], datetime_start=datetime.datetime(2025, 3, 24, 23, 11, 46, 95594), datetime_complete=datetime.datetime(2025, 3, 24, 23, 14, 40, 830379), params={'optimizer': 'Adam', 'lr': 1.5598351295548222e-05}, user_attrs={'artifact_id': '9ba225c5-06f9-4789-bca2-7ce7fddc2a53'}, system_attrs={'artifacts:9ba225c5-06f9-4789-bca2-7ce7fddc2a53': '{"artifact_id": "9ba225c5-06f9-4789-bca2-7ce7fddc2a53", "filename": "model_trial_217.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=218, value=None),
#  FrozenTrial(number=229, state=TrialState.COMPLETE, values=[6046.986253416638, 0.017098227265033912], datetime_start=datetime.datetime(2025, 3, 24, 23, 17, 35, 650940), datetime_complete=datetime.datetime(2025, 3, 24, 23, 20, 30, 355525), params={'optimizer': 'Adam', 'lr': 4.455946161350674e-06}, user_attrs={'artifact_id': '59807214-fa7b-4f2a-80dd-7f53cf8b191a'}, system_attrs={'artifacts:59807214-fa7b-4f2a-80dd-7f53cf8b191a': '{"artifact_id": "59807214-fa7b-4f2a-80dd-7f53cf8b191a", "filename": "model_trial_229.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=230, value=None),
#  FrozenTrial(number=232, state=TrialState.COMPLETE, values=[5037.688374129252, 0.003949149899323668], datetime_start=datetime.datetime(2025, 3, 24, 23, 18, 43, 672321), datetime_complete=datetime.datetime(2025, 3, 24, 23, 21, 36, 578057), params={'optimizer': 'Adam', 'lr': 1.311803371331458e-05}, user_attrs={'artifact_id': '811f8eb3-c32f-44b7-b38b-a3a857c7e760'}, system_attrs={'artifacts:811f8eb3-c32f-44b7-b38b-a3a857c7e760': '{"artifact_id": "811f8eb3-c32f-44b7-b38b-a3a857c7e760", "filename": "model_trial_232.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=233, value=None),
#  FrozenTrial(number=233, state=TrialState.COMPLETE, values=[4158.923977196153, 0.001170333003823861], datetime_start=datetime.datetime(2025, 3, 24, 23, 18, 44, 718344), datetime_complete=datetime.datetime(2025, 3, 24, 23, 21, 41, 608164), params={'optimizer': 'Adam', 'lr': 1.3441004874338594e-05}, user_attrs={'artifact_id': '72803605-ad95-4384-811b-422fd89870e9'}, system_attrs={'artifacts:72803605-ad95-4384-811b-422fd89870e9': '{"artifact_id": "72803605-ad95-4384-811b-422fd89870e9", "filename": "model_trial_233.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=234, value=None),
#  FrozenTrial(number=236, state=TrialState.COMPLETE, values=[5043.678261304226, 0.003962801279025682], datetime_start=datetime.datetime(2025, 3, 24, 23, 20, 43, 751036), datetime_complete=datetime.datetime(2025, 3, 24, 23, 23, 42, 604911), params={'optimizer': 'Adam', 'lr': 1.3105466259099796e-05}, user_attrs={'artifact_id': 'f90aff91-f962-4909-8159-9bcc0b8b82d2'}, system_attrs={'artifacts:f90aff91-f962-4909-8159-9bcc0b8b82d2': '{"artifact_id": "f90aff91-f962-4909-8159-9bcc0b8b82d2", "filename": "model_trial_236.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=237, value=None),
#  FrozenTrial(number=237, state=TrialState.COMPLETE, values=[5341.76207114254, 0.006460679306517035], datetime_start=datetime.datetime(2025, 3, 24, 23, 20, 48, 132040), datetime_complete=datetime.datetime(2025, 3, 24, 23, 23, 43, 446617), params={'optimizer': 'Adam', 'lr': 1.176143608118074e-05}, user_attrs={'artifact_id': '731c1ca5-949e-4c98-b965-c9354174f836'}, system_attrs={'artifacts:731c1ca5-949e-4c98-b965-c9354174f836': '{"artifact_id": "731c1ca5-949e-4c98-b965-c9354174f836", "filename": "model_trial_237.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=238, value=None),
#  FrozenTrial(number=271, state=TrialState.COMPLETE, values=[6320.363538279844, 0.025069373087216344], datetime_start=datetime.datetime(2025, 3, 24, 23, 38, 5, 24855), datetime_complete=datetime.datetime(2025, 3, 24, 23, 41, 0, 240361), params={'optimizer': 'SGD', 'lr': 1.002795205069309e-09}, user_attrs={'artifact_id': 'b78267ae-2ada-427a-ae61-5c008cee8656'}, system_attrs={'artifacts:b78267ae-2ada-427a-ae61-5c008cee8656': '{"artifact_id": "b78267ae-2ada-427a-ae61-5c008cee8656", "filename": "model_trial_271.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=272, value=None),
#  FrozenTrial(number=278, state=TrialState.COMPLETE, values=[6115.566028968673, 0.0197829985677094], datetime_start=datetime.datetime(2025, 3, 24, 23, 41, 21, 427211), datetime_complete=datetime.datetime(2025, 3, 24, 23, 44, 16, 107709), params={'optimizer': 'SGD', 'lr': 1.93491479797845e-09}, user_attrs={'artifact_id': '41fb6e96-f339-475f-b712-7191e8e030c7'}, system_attrs={'artifacts:41fb6e96-f339-475f-b712-7191e8e030c7': '{"artifact_id": "41fb6e96-f339-475f-b712-7191e8e030c7", "filename": "model_trial_278.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=279, value=None),
#  FrozenTrial(number=280, state=TrialState.COMPLETE, values=[886.0216336572614, 7.298495790878223e-07], datetime_start=datetime.datetime(2025, 3, 24, 23, 41, 50, 940659), datetime_complete=datetime.datetime(2025, 3, 24, 23, 44, 43, 732812), params={'optimizer': 'Adam', 'lr': 1.9887551799805936e-05}, user_attrs={'artifact_id': 'c2a4752d-d7a8-4cb5-8019-55635ab4620c'}, system_attrs={'artifacts:c2a4752d-d7a8-4cb5-8019-55635ab4620c': '{"artifact_id": "c2a4752d-d7a8-4cb5-8019-55635ab4620c", "filename": "model_trial_280.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=281, value=None),
#  FrozenTrial(number=283, state=TrialState.COMPLETE, values=[519.7240435066573, 2.3656990686660447e-07], datetime_start=datetime.datetime(2025, 3, 24, 23, 43, 54, 559605), datetime_complete=datetime.datetime(2025, 3, 24, 23, 46, 50, 248116), params={'optimizer': 'Adam', 'lr': 2.0559056784984803e-05}, user_attrs={'artifact_id': '0ac2b555-0261-4583-a2e8-e838eeb679b1'}, system_attrs={'artifacts:0ac2b555-0261-4583-a2e8-e838eeb679b1': '{"artifact_id": "0ac2b555-0261-4583-a2e8-e838eeb679b1", "filename": "model_trial_283.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=284, value=None),
#  FrozenTrial(number=287, state=TrialState.COMPLETE, values=[13.609411913358114, 1.049974654582575e-10], datetime_start=datetime.datetime(2025, 3, 24, 23, 45, 21, 958823), datetime_complete=datetime.datetime(2025, 3, 24, 23, 48, 18, 939969), params={'optimizer': 'SGD', 'lr': 2.408527816196201e-05}, user_attrs={'artifact_id': '3a28e4fb-082b-4abc-8335-ca2dd56e14df'}, system_attrs={'artifacts:3a28e4fb-082b-4abc-8335-ca2dd56e14df': '{"artifact_id": "3a28e4fb-082b-4abc-8335-ca2dd56e14df", "filename": "model_trial_287.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=288, value=None),
#  FrozenTrial(number=293, state=TrialState.COMPLETE, values=[5108.838008842048, 0.00400643237889926], datetime_start=datetime.datetime(2025, 3, 24, 23, 48, 18, 974592), datetime_complete=datetime.datetime(2025, 3, 24, 23, 51, 16, 32127), params={'optimizer': 'Adam', 'lr': 1.091677440846759e-05}, user_attrs={'artifact_id': 'cdbe316e-a4cd-4877-bbfd-1a00f1150a67'}, system_attrs={'artifacts:cdbe316e-a4cd-4877-bbfd-1a00f1150a67': '{"artifact_id": "cdbe316e-a4cd-4877-bbfd-1a00f1150a67", "filename": "model_trial_293.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=294, value=None),
#  FrozenTrial(number=294, state=TrialState.COMPLETE, values=[4664.560716189868, 0.0023870991943010025], datetime_start=datetime.datetime(2025, 3, 24, 23, 49, 35, 770450), datetime_complete=datetime.datetime(2025, 3, 24, 23, 52, 30, 680523), params={'optimizer': 'Adam', 'lr': 1.3329814775023177e-05}, user_attrs={'artifact_id': '6fc66e67-4a97-4b08-894f-d3bf0d62fb94'}, system_attrs={'artifacts:6fc66e67-4a97-4b08-894f-d3bf0d62fb94': '{"artifact_id": "6fc66e67-4a97-4b08-894f-d3bf0d62fb94", "filename": "model_trial_294.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=295, value=None),
#  FrozenTrial(number=296, state=TrialState.COMPLETE, values=[5120.109304592909, 0.004180409824841232], datetime_start=datetime.datetime(2025, 3, 24, 23, 50, 6, 42087), datetime_complete=datetime.datetime(2025, 3, 24, 23, 53, 1, 495258), params={'optimizer': 'Adam', 'lr': 1.3030107523946297e-05}, user_attrs={'artifact_id': 'e8ee1209-71bb-47ed-a4d4-30dded159d07'}, system_attrs={'artifacts:e8ee1209-71bb-47ed-a4d4-30dded159d07': '{"artifact_id": "e8ee1209-71bb-47ed-a4d4-30dded159d07", "filename": "model_trial_296.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=297, value=None),
#  FrozenTrial(number=297, state=TrialState.COMPLETE, values=[5563.456731651146, 0.008095098085345883], datetime_start=datetime.datetime(2025, 3, 24, 23, 50, 28, 465754), datetime_complete=datetime.datetime(2025, 3, 24, 23, 53, 20, 980748), params={'optimizer': 'Adam', 'lr': 1.1944575106304164e-05}, user_attrs={'artifact_id': '9c2b4e08-16bd-4a4a-a158-20cbed1fafae'}, system_attrs={'artifacts:9c2b4e08-16bd-4a4a-a158-20cbed1fafae': '{"artifact_id": "9c2b4e08-16bd-4a4a-a158-20cbed1fafae", "filename": "model_trial_297.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=298, value=None),
# ...
#  FrozenTrial(number=509, state=TrialState.COMPLETE, values=[2336.267439752254, 5.389873977032663e-05], datetime_start=datetime.datetime(2025, 3, 25, 1, 34, 16, 744497), datetime_complete=datetime.datetime(2025, 3, 25, 1, 37, 11, 517576), params={'optimizer': 'RMSprop', 'lr': 2.7679768042213684e-05}, user_attrs={'artifact_id': 'f581cda5-2058-464f-9a3f-3eb8754acbea'}, system_attrs={'artifacts:f581cda5-2058-464f-9a3f-3eb8754acbea': '{"artifact_id": "f581cda5-2058-464f-9a3f-3eb8754acbea", "filename": "model_trial_509.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=510, value=None),
#  FrozenTrial(number=511, state=TrialState.COMPLETE, values=[6007.583227629229, 0.015531026667894653], datetime_start=datetime.datetime(2025, 3, 25, 1, 34, 29, 20362), datetime_complete=datetime.datetime(2025, 3, 25, 1, 37, 24, 140391), params={'optimizer': 'RMSprop', 'lr': 7.600025483043713e-06}, user_attrs={'artifact_id': 'e92ac264-8853-4c3f-934b-11957d85a50d'}, system_attrs={'artifacts:e92ac264-8853-4c3f-934b-11957d85a50d': '{"artifact_id": "e92ac264-8853-4c3f-934b-11957d85a50d", "filename": "model_trial_511.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=512, value=None),
#  FrozenTrial(number=513, state=TrialState.COMPLETE, values=[6063.017668710779, 0.017724090700579648], datetime_start=datetime.datetime(2025, 3, 25, 1, 35, 4, 613898), datetime_complete=datetime.datetime(2025, 3, 25, 1, 38, 0, 517085), params={'optimizer': 'RMSprop', 'lr': 5.703997678522517e-06}, user_attrs={'artifact_id': '9b3d8add-f433-4b59-a603-b5062ce886ac'}, system_attrs={'artifacts:9b3d8add-f433-4b59-a603-b5062ce886ac': '{"artifact_id": "9b3d8add-f433-4b59-a603-b5062ce886ac", "filename": "model_trial_513.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=514, value=None),
#  FrozenTrial(number=518, state=TrialState.COMPLETE, values=[6210.066265513353, 0.021507370284836062], datetime_start=datetime.datetime(2025, 3, 25, 1, 37, 44, 641680), datetime_complete=datetime.datetime(2025, 3, 25, 1, 40, 44, 98717), params={'optimizer': 'RMSprop', 'lr': 4.609862373524137e-06}, user_attrs={'artifact_id': '49605ec1-fb9a-45e1-ad6d-008f788f3c7e'}, system_attrs={'artifacts:49605ec1-fb9a-45e1-ad6d-008f788f3c7e': '{"artifact_id": "49605ec1-fb9a-45e1-ad6d-008f788f3c7e", "filename": "model_trial_518.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=519, value=None),
#  FrozenTrial(number=522, state=TrialState.COMPLETE, values=[4777.180034691864, 0.002768143572163062], datetime_start=datetime.datetime(2025, 3, 25, 1, 40, 15, 48367), datetime_complete=datetime.datetime(2025, 3, 25, 1, 43, 10, 960616), params={'optimizer': 'RMSprop', 'lr': 1.6180342430406592e-05}, user_attrs={'artifact_id': '4b209cdf-70fc-438b-bb3d-7978f975f3b5'}, system_attrs={'artifacts:4b209cdf-70fc-438b-bb3d-7978f975f3b5': '{"artifact_id": "4b209cdf-70fc-438b-bb3d-7978f975f3b5", "filename": "model_trial_522.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=523, value=None),
#  FrozenTrial(number=528, state=TrialState.COMPLETE, values=[5951.900972188522, 0.014416825968068406], datetime_start=datetime.datetime(2025, 3, 25, 1, 43, 11, 2938), datetime_complete=datetime.datetime(2025, 3, 25, 1, 46, 8, 34112), params={'optimizer': 'RMSprop', 'lr': 9.376021094644821e-06}, user_attrs={'artifact_id': 'ad7f669f-2682-45d1-b388-a1c8fdf5e5a7'}, system_attrs={'artifacts:ad7f669f-2682-45d1-b388-a1c8fdf5e5a7': '{"artifact_id": "ad7f669f-2682-45d1-b388-a1c8fdf5e5a7", "filename": "model_trial_528.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=529, value=None),
#  FrozenTrial(number=529, state=TrialState.COMPLETE, values=[5821.789800502795, 0.012625443651296007], datetime_start=datetime.datetime(2025, 3, 25, 1, 43, 13, 534373), datetime_complete=datetime.datetime(2025, 3, 25, 1, 46, 9, 440091), params={'optimizer': 'Adam', 'lr': 9.541491571255668e-06}, user_attrs={'artifact_id': 'bb6dc8c3-3943-42c9-829f-484f34efe41b'}, system_attrs={'artifacts:bb6dc8c3-3943-42c9-829f-484f34efe41b': '{"artifact_id": "bb6dc8c3-3943-42c9-829f-484f34efe41b", "filename": "model_trial_529.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=530, value=None),
#  FrozenTrial(number=531, state=TrialState.COMPLETE, values=[2266.9844090230954, 4.441566961199971e-05], datetime_start=datetime.datetime(2025, 3, 25, 1, 43, 50, 610862), datetime_complete=datetime.datetime(2025, 3, 25, 1, 46, 47, 146184), params={'optimizer': 'Adam', 'lr': 1.6275702252761048e-05}, user_attrs={'artifact_id': '2fe94179-490f-4e94-bcbd-c4b0904dc60c'}, system_attrs={'artifacts:2fe94179-490f-4e94-bcbd-c4b0904dc60c': '{"artifact_id": "2fe94179-490f-4e94-bcbd-c4b0904dc60c", "filename": "model_trial_531.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=532, value=None),
#  FrozenTrial(number=532, state=TrialState.COMPLETE, values=[743.3034973685958, 6.569112088856666e-07], datetime_start=datetime.datetime(2025, 3, 25, 1, 45, 22, 215616), datetime_complete=datetime.datetime(2025, 3, 25, 1, 48, 15, 358366), params={'optimizer': 'Adam', 'lr': 1.732354728482936e-05}, user_attrs={'artifact_id': '29629f2b-4e70-4310-b1bc-9d3e56313f18'}, system_attrs={'artifacts:29629f2b-4e70-4310-b1bc-9d3e56313f18': '{"artifact_id": "29629f2b-4e70-4310-b1bc-9d3e56313f18", "filename": "model_trial_532.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=533, value=None),
#  FrozenTrial(number=533, state=TrialState.COMPLETE, values=[2890.9445866522506, 0.00012025688128124927], datetime_start=datetime.datetime(2025, 3, 25, 1, 45, 55, 372208), datetime_complete=datetime.datetime(2025, 3, 25, 1, 48, 51, 248052), params={'optimizer': 'Adam', 'lr': 1.4819852285481422e-05}, user_attrs={'artifact_id': '7112bf36-c391-49e1-bba3-fcc5a2cd997a'}, system_attrs={'artifacts:7112bf36-c391-49e1-bba3-fcc5a2cd997a': '{"artifact_id": "7112bf36-c391-49e1-bba3-fcc5a2cd997a", "filename": "model_trial_533.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=534, value=None),
#  FrozenTrial(number=536, state=TrialState.COMPLETE, values=[3751.680094023739, 0.0007509970645224496], datetime_start=datetime.datetime(2025, 3, 25, 1, 46, 42, 129089), datetime_complete=datetime.datetime(2025, 3, 25, 1, 49, 41, 741927), params={'optimizer': 'Adam', 'lr': 1.644975809825341e-05}, user_attrs={'artifact_id': '29a5edfa-65e4-4332-88b1-22bf84ea878c'}, system_attrs={'artifacts:29a5edfa-65e4-4332-88b1-22bf84ea878c': '{"artifact_id": "29a5edfa-65e4-4332-88b1-22bf84ea878c", "filename": "model_trial_536.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=537, value=None),
#  FrozenTrial(number=537, state=TrialState.COMPLETE, values=[2570.4346812050985, 7.827541487009918e-05], datetime_start=datetime.datetime(2025, 3, 25, 1, 46, 47, 196934), datetime_complete=datetime.datetime(2025, 3, 25, 1, 49, 43, 220608), params={'optimizer': 'Adam', 'lr': 1.756048972018471e-05}, user_attrs={'artifact_id': 'db11190d-0517-4b3f-b25f-5bf8e013c937'}, system_attrs={'artifacts:db11190d-0517-4b3f-b25f-5bf8e013c937': '{"artifact_id": "db11190d-0517-4b3f-b25f-5bf8e013c937", "filename": "model_trial_537.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=538, value=None),
#  FrozenTrial(number=538, state=TrialState.COMPLETE, values=[4339.847736120565, 0.0012952167611980196], datetime_start=datetime.datetime(2025, 3, 25, 1, 48, 15, 406639), datetime_complete=datetime.datetime(2025, 3, 25, 1, 51, 9, 392398), params={'optimizer': 'Adam', 'lr': 1.4433061813513134e-05}, user_attrs={'artifact_id': 'e7fd6f72-1bda-43a7-bf62-fcc846c39c08'}, system_attrs={'artifacts:e7fd6f72-1bda-43a7-bf62-fcc846c39c08': '{"artifact_id": "e7fd6f72-1bda-43a7-bf62-fcc846c39c08", "filename": "model_trial_538.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=539, value=None),
#  FrozenTrial(number=545, state=TrialState.COMPLETE, values=[6217.762647844767, 0.021723287692262568], datetime_start=datetime.datetime(2025, 3, 25, 1, 51, 47, 658228), datetime_complete=datetime.datetime(2025, 3, 25, 1, 54, 41, 907828), params={'optimizer': 'SGD', 'lr': 1.367605926088519e-09}, user_attrs={'artifact_id': '65f3bdcf-20b0-4df2-b6e0-aac8ad013966'}, system_attrs={'artifacts:65f3bdcf-20b0-4df2-b6e0-aac8ad013966': '{"artifact_id": "65f3bdcf-20b0-4df2-b6e0-aac8ad013966", "filename": "model_trial_545.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=546, value=None),
#  FrozenTrial(number=558, state=TrialState.COMPLETE, values=[6050.159109273215, 0.01726625594786473], datetime_start=datetime.datetime(2025, 3, 25, 1, 57, 49, 464856), datetime_complete=datetime.datetime(2025, 3, 25, 2, 0, 42, 953458), params={'optimizer': 'SGD', 'lr': 2.1781603040111158e-07}, user_attrs={'artifact_id': '61052e52-fdc5-4d4a-af34-5eb5a8f25f56'}, system_attrs={'artifacts:61052e52-fdc5-4d4a-af34-5eb5a8f25f56': '{"artifact_id": "61052e52-fdc5-4d4a-af34-5eb5a8f25f56", "filename": "model_trial_558.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=559, value=None),
#  FrozenTrial(number=567, state=TrialState.COMPLETE, values=[6111.056422554648, 0.01921470149199904], datetime_start=datetime.datetime(2025, 3, 25, 2, 1, 33, 759565), datetime_complete=datetime.datetime(2025, 3, 25, 2, 4, 31, 225799), params={'optimizer': 'SGD', 'lr': 1.0002385269666637e-09}, user_attrs={'artifact_id': 'a36a32e1-b4da-48ef-94f6-143d1afb7628'}, system_attrs={'artifacts:a36a32e1-b4da-48ef-94f6-143d1afb7628': '{"artifact_id": "a36a32e1-b4da-48ef-94f6-143d1afb7628", "filename": "model_trial_567.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=568, value=None),
#  FrozenTrial(number=576, state=TrialState.COMPLETE, values=[275.941764052248, 5.625404599064366e-08], datetime_start=datetime.datetime(2025, 3, 25, 2, 6, 30, 295056), datetime_complete=datetime.datetime(2025, 3, 25, 2, 9, 25, 242592), params={'optimizer': 'Adam', 'lr': 2.1340443733216314e-05}, user_attrs={'artifact_id': '71b1c908-0914-4291-b153-7ede79720f52'}, system_attrs={'artifacts:71b1c908-0914-4291-b153-7ede79720f52': '{"artifact_id": "71b1c908-0914-4291-b153-7ede79720f52", "filename": "model_trial_576.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=577, value=None),
#  FrozenTrial(number=578, state=TrialState.COMPLETE, values=[6234.852222902842, 0.022586076558049818], datetime_start=datetime.datetime(2025, 3, 25, 2, 7, 9, 598774), datetime_complete=datetime.datetime(2025, 3, 25, 2, 10, 5, 23243), params={'optimizer': 'Adam', 'lr': 1.7333325777672774e-09}, user_attrs={'artifact_id': '801a5c92-727f-4c4a-b97b-50ad8f36c1bd'}, system_attrs={'artifacts:801a5c92-727f-4c4a-b97b-50ad8f36c1bd': '{"artifact_id": "801a5c92-727f-4c4a-b97b-50ad8f36c1bd", "filename": "model_trial_578.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=579, value=None),
#  FrozenTrial(number=582, state=TrialState.COMPLETE, values=[6289.616656634802, 0.024700908860673255], datetime_start=datetime.datetime(2025, 3, 25, 2, 9, 25, 292766), datetime_complete=datetime.datetime(2025, 3, 25, 2, 12, 20, 90363), params={'optimizer': 'Adam', 'lr': 1.8499395350353415e-09}, user_attrs={'artifact_id': 'fbfd594c-0a53-4a45-9dcb-fdcb0bc4fe93'}, system_attrs={'artifacts:fbfd594c-0a53-4a45-9dcb-fdcb0bc4fe93': '{"artifact_id": "fbfd594c-0a53-4a45-9dcb-fdcb0bc4fe93", "filename": "model_trial_582.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=583, value=None),
#  FrozenTrial(number=598, state=TrialState.COMPLETE, values=[5423.8152246275395, 0.007501119738975313], datetime_start=datetime.datetime(2025, 3, 25, 2, 19, 24, 434250), datetime_complete=datetime.datetime(2025, 3, 25, 2, 22, 23, 950021), params={'optimizer': 'RMSprop', 'lr': 1.8779197765852754e-05}, user_attrs={'artifact_id': 'de4cb4ae-d30f-4c68-aada-fd7c28091837'}, system_attrs={'artifacts:de4cb4ae-d30f-4c68-aada-fd7c28091837': '{"artifact_id": "de4cb4ae-d30f-4c68-aada-fd7c28091837", "filename": "model_trial_598.pt", "mimetype": "application/octet-stream", "encoding": null}'}, intermediate_values={}, distributions={'optimizer': CategoricalDistribution(choices=('Adam', 'RMSprop', 'SGD')), 'lr': FloatDistribution(high=0.01, log=True, low=1e-09, step=None)}, trial_id=599, value=None)]

# %% [markdown]
# ## Artifact

# %%
artifact_path = trial.artifacts.get("artifact_file", None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 artifact_path = trial.artifacts.get("artifact_file", None)
#
# AttributeError: 'FrozenTrial' object has no attribute 'artifacts'

# %%
artifact_base_path = "../data/optuna/artifacts/"
artifact_path = artifact_base_path+ trial.user_attrs['artifact_id']

# %%
# Load an existing study from your storage (e.g., SQLite)
study = optuna.load_study(
    study_name="three_body_preliminary",
    storage="sqlite:///../optuna/database/three_body_preliminary.db"
)

# Retrieve the trial (here we choose trial number 1, adjust as needed)
trial = next(t for t in study.trials if t.number == 1)

# Retrieve the artifact_id stored as a user attribute during the upload
artifact_id = trial.user_attrs["artifact_id"]
#artifact_base_path = "../data/optuna/artifacts/"
#file_path = artifact_base_path+f"/model_trial_{trial.number}.pt"
file_path = f"./downloaded_artifacts/model_trial_{trial.number}.txt"
artifact_store = FileSystemArtifactStore(base_path=artifact_base_path)


# Download the artifact without specifying an output directory
optuna.artifacts.download_artifact(
    artifact_id=artifact_id,
    file_path=file_path,
    artifact_store=artifact_store
    )
print(f"Artifact downloaded to: {file_path}")

# Optionally, if you want the file in a specific directory, move it manually:
#output_dir = "downloaded_artifacts"
#os.makedirs(output_dir, exist_ok=True)
#destination_path = os.path.join(output_dir, os.path.basename(artifact_path))
#shutil.move(artifact_path, destination_path)
#print(f"Artifact moved to: {destination_path}")

# If the artifact is a PyTorch model state dict, you can load it:
#state_dict = torch.load(destination_path)
#print("Loaded model state dict keys:", list(state_dict.keys()))
# Out:
# Artifact downloaded to: ./downloaded_artifacts/model_trial_1.txt
